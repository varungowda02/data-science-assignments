# %%
import pandas as pd
df=pd.read_excel("/content/drive/MyDrive/DS assigment/Random Forest/glass.xlsx", sheet_name='glass')
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.shape
# Out:
# (214, 10)

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
df.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
df.nunique()
# Out:
# RI      178
# Na      142
# Mg       94
# Al      118
# Si      133
# K        65
# Ca      143
# Ba       34
# Fe       32
# Type      6
# dtype: int64

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df[df.duplicated]
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 39  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [RI, Na, Mg, Al, Si, K, Ca, Ba, Fe, Type]
# Index: []

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'RI'}>, <Axes: title={'center': 'Na'}>,
#         <Axes: title={'center': 'Mg'}>],
#        [<Axes: title={'center': 'Al'}>, <Axes: title={'center': 'Si'}>,
#         <Axes: title={'center': 'K'}>],
#        [<Axes: title={'center': 'Ca'}>, <Axes: title={'center': 'Ba'}>,
#         <Axes: title={'center': 'Fe'}>],
#        [<Axes: title={'center': 'Type'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for i in df.columns:
  plt.figure(figsize=(35,5))
  plt.title(i)
  sns.boxplot(df[i], orient='h')
  plt.show()

# %%
sns.pairplot(df)

# %%
for i in df.columns:
  plt.figure(figsize=(10,8))
  sns.distplot(df[i])
  plt.show()
# Out:
# <ipython-input-16-2fffeba48e33>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-16-2fffeba48e33>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i])
# <ipython-input-16-2fffeba48e33>:3: UserWarning:
#
# ...

# %%
from scipy.stats import skew, kurtosis
for i in df.columns:
  print(i)
  print(f"Skewness of {i}: ",skew(df[i]))
  print(f"Kurtosis of {i}: ",kurtosis(df[i]), "\n")
# Out:
# RI
# Skewness of RI:  1.6363888397604887
# Kurtosis of RI:  4.893360445458023
#
# Na
# Skewness of Na:  0.46241250566806297
# Kurtosis of Na:  2.983977039610834
#
# Mg
# Skewness of Mg:  -1.1380089055903053
# Kurtosis of Mg:  -0.44443324142770235
#
# Al
# Skewness of Al:  0.9317802819693977
# Kurtosis of Al:  2.0391666180759325
#
# Si
# Skewness of Si:  -0.7393917375081076
# Kurtosis of Si:  2.923355630764953
#
# K
# Skewness of K:  6.499243614743353
# Kurtosis of K:  53.24264678839453
#
# Ca
# Skewness of Ca:  2.0362818064656816
# Kurtosis of Ca:  6.48744497948746
#
# Ba
# Skewness of Ba:  3.3827105620531985
# Kurtosis of Ba:  12.146211141718753
#
# Fe
# Skewness of Fe:  1.734845022250602
# Kurtosis of Fe:  2.5445588650756354
#
# Type
# Skewness of Type:  1.1010363557258223
# Kurtosis of Type:  -0.31535381683019237

# %% [markdown]
# # Skewness
#
# Skewness measures the asymmetry of the data distribution.
#
# - A **positive skewness** value indicates that the distribution is skewed to the right (tail on the right side is longer). Features like K, Ca, Ba, and Fe exhibit significant positive skewness.
# - A **negative skewness** value indicates that the distribution is skewed to the left (tail on the left side is longer). Mg and Si show negative skewness.
# - A skewness value close to **0** suggests a relatively symmetrical distribution. RI, Na, Al, and Type have skewness values closer to 0, indicating less skewness compared to other features.
#
# # Kurtosis
#
# Kurtosis measures the "tailedness" of the data distribution, or how often outliers occur.
#
# - A **positive kurtosis** value (leptokurtic distribution) indicates a distribution with heavy tails and a sharp peak. This means there is a higher probability of extreme values. RI, Na, Al, K, Ca, Ba, and Fe have positive kurtosis. K shows a very high kurtosis, indicating a very heavy tail with potential outliers.
# - A **negative kurtosis** value (platykurtic distribution) indicates a distribution with lighter tails and a flatter peak. Mg and Type have negative kurtosis, suggesting fewer outliers compared to other features.
#
# # Overall Interpretation
#
# - **Features with High Skewness**: K, Ca, Ba, and Fe show substantial positive skewness. This indicates their distributions are skewed to the right, with potential outliers on the higher end. Transformations like logarithmic or square root transformations might be considered to reduce skewness for these features if required by your modeling technique.
# - **Features with High Kurtosis**: K stands out with very high kurtosis, indicating a high frequency of extreme values. This warrants further investigation into potential outliers in the K feature. RI, Na, Al, Ca, Ba, and Fe also exhibit positive kurtosis, suggesting heavier tails than a normal distribution.
# - **Features with Negative Skewness and Kurtosis**: Mg has negative skewness and kurtosis. This indicates a distribution skewed to the left with lighter tails. Type has negative kurtosis and slight positive skewness.
# - **Impact on Modeling**: Skewness and kurtosis can impact the performance of certain machine learning models that assume normality. Consider data transformations or robust modeling techniques if necessary to address these effects.

# %%
for i in df.columns:
  plt.figure(figsize=(10,8))
  plt.title(i)
  sns.histplot(df[i], kde=True)
  plt.show()

# %%
c=df.corr()
c
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.198802 -0.127526 -0.400973 -0.539000 -0.287645  0.811183
# Na   -0.198802  1.000000 -0.278420  0.167735 -0.064885 -0.264158 -0.278194
# Mg   -0.127526 -0.278420  1.000000 -0.479575 -0.162437  0.007617 -0.446197
# Al   -0.400973  0.167735 -0.479575  1.000000 -0.016195  0.323683 -0.258068
# Si   -0.539000 -0.064885 -0.162437 -0.016195  1.000000 -0.197281 -0.207145
# K    -0.287645 -0.264158  0.007617  0.323683 -0.197281  1.000000 -0.317032
# Ca    0.811183 -0.278194 -0.446197 -0.258068 -0.207145 -0.317032  1.000000
# Ba    0.001679  0.329080 -0.491818  0.480642 -0.104389 -0.043653 -0.112208
# Fe    0.147083 -0.239374  0.085426 -0.080583 -0.097717 -0.009372  0.126314
# Type -0.160140  0.508837 -0.744195  0.597432  0.147725 -0.012455  0.002677
#
#             Ba        Fe      Type
# RI    0.001679  0.147083 -0.160140
# Na    0.329080 -0.239374  0.508837
# Mg   -0.491818  0.085426 -0.744195
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(c, annot=True)
plt.show()

# %% [markdown]
# # Correlation Analysis
#
# The correlation matrix shows the linear relationship between pairs of variables. The values range from -1 to +1, where:
#
# - **+1** indicates a perfect positive correlation (as one variable increases, the other increases).
# - **-1** indicates a perfect negative correlation (as one variable increases, the other decreases).
# - **0** indicates no linear correlation.
#
# ## Key Observations
#
# ### Strong Positive Correlations:
# - **RI and Ca** have a strong positive correlation (0.81). This suggests that as the refractive index (RI) increases, the calcium content (Ca) also tends to increase.
#
# ### Moderate Positive Correlations:
# - **Na and Type** have a moderate positive correlation (0.51).
# - **Al and Type** have a moderate positive correlation (0.60).
# - **Ba and Type** have a moderate positive correlation (0.57).
# - **Al and Ba** have a moderate positive correlation (0.48).
#
# ### Moderate Negative Correlations:
# - **Mg and Type** have a moderate negative correlation (-0.74). This suggests that as the magnesium content (Mg) increases, the glass type (Type) tends to decrease.
# - **RI and Si** have a moderate negative correlation (-0.54).
# - **Mg and Al** have a moderate negative correlation (-0.48).
# - **Mg and Ba** have a moderate negative correlation (-0.49).
# - **Mg and Ca** have a moderate negative correlation (-0.45).
#
# ### Weak Correlations:
# - Most other pairs of variables show weak correlations (close to 0), indicating little to no linear relationship between them.
#
# ## Overall Interpretation
# - **RI and Ca** are strongly positively correlated.
# - **Mg** has a moderate negative correlation with **Type**, suggesting its importance in determining the glass type.
# - **Na**, **Al**, and **Ba** show moderate positive correlations with **Type**, indicating their potential influence on the glass type.
# - Other variables have relatively weak correlations, suggesting less direct influence on each other.

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
import numpy as np
from scipy import stats

# %%
threshold=3
z_score=np.abs(stats.zscore(df))
df=df[(z_score<3).all(axis=1)]

# %%
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 208  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.0     7
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
#
# [193 rows x 10 columns]

# %%
df.shape
# Out:
# (193, 10)

# %%
df.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type      int64
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df.loc[:, df.columns != 'Type']=scaler.fit_transform(df.loc[:, df.columns!='Type'])
df
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    1.308474  0.338598  1.235597 -0.747371 -1.627964 -1.326595 -0.071659
# 1   -0.189678  0.711257  0.554625 -0.154343  0.007672  0.166308 -1.003126
# 2   -0.819783  0.174628  0.516368  0.256215  0.455320 -0.153600 -1.053749
# 3   -0.167646 -0.302375  0.623487 -0.314005 -0.198935  0.486216 -0.608265
# 4   -0.273398 -0.212937  0.569928 -0.428049  0.610274  0.415125 -0.760134
# ..        ...       ...       ...       ...       ...       ...       ...
# 208 -0.722844  1.426762 -2.199867  2.993267  0.214279 -1.539867  0.637065
# 209 -0.797751  1.083916 -2.199867  3.312590 -0.198935 -1.255504  0.363700
# 210 -0.524559  2.246611 -2.199867  1.282609  0.575840 -1.539867 -0.426022
# 211  1.149847  1.411856 -2.199867  1.351036  1.195660 -1.539867 -0.385523
# 212 -0.674374  1.441668 -2.199867  1.168566  1.522787 -1.539867 -0.345024
#
#            Ba        Fe  Type
# 0   -0.347296 -0.605187     1
# ...

# %%
x=df.drop('Type', axis=1)
x
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    1.308474  0.338598  1.235597 -0.747371 -1.627964 -1.326595 -0.071659
# 1   -0.189678  0.711257  0.554625 -0.154343  0.007672  0.166308 -1.003126
# 2   -0.819783  0.174628  0.516368  0.256215  0.455320 -0.153600 -1.053749
# 3   -0.167646 -0.302375  0.623487 -0.314005 -0.198935  0.486216 -0.608265
# 4   -0.273398 -0.212937  0.569928 -0.428049  0.610274  0.415125 -0.760134
# ..        ...       ...       ...       ...       ...       ...       ...
# 208 -0.722844  1.426762 -2.199867  2.993267  0.214279 -1.539867  0.637065
# 209 -0.797751  1.083916 -2.199867  3.312590 -0.198935 -1.255504  0.363700
# 210 -0.524559  2.246611 -2.199867  1.282609  0.575840 -1.539867 -0.426022
# 211  1.149847  1.411856 -2.199867  1.351036  1.195660 -1.539867 -0.385523
# 212 -0.674374  1.441668 -2.199867  1.168566  1.522787 -1.539867 -0.345024
#
#            Ba        Fe
# 0   -0.347296 -0.605187
# 1   -0.347296 -0.605187
# ...

# %%
y=df.Type
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 208    7
# 209    7
# 210    7
# 211    7
# 212    7
# Name: Type, Length: 193, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((154, 9), (39, 9), (154,), (39,))

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1, 1, 2, 3, 2, 1, 1, 1, 1, 1, 2, 2, 2, 2, 5, 1, 2, 2, 2, 1, 5, 2,
#        2, 1, 1, 2, 1, 5, 1, 1, 2, 6, 2, 2, 7, 2, 5, 1, 6])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
# Out:
# Accuracy Score: 0.7435897435897436

# %%
print(f"Confusion Matrix: \n{confusion_matrix(y_test, y_pred)}")
# Out:
# Confusion Matrix:
# [[10  4  0  0  0  0]
#  [ 1 11  0  0  0  0]
#  [ 4  1  1  0  0  0]
#  [ 0  0  0  4  0  0]
#  [ 0  0  0  0  2  0]
#  [ 0  0  0  0  0  1]]

# %%
plt.figure(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
plt.show()

# %%
print(f"Classification Report:\n {classification_report(y_test, y_pred)}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.67      0.71      0.69        14
#            2       0.69      0.92      0.79        12
#            3       1.00      0.17      0.29         6
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         1
#
#     accuracy                           0.74        39
#    macro avg       0.89      0.80      0.79        39
# weighted avg       0.78      0.74      0.71        39

# %%
from sklearn.tree import export_graphviz
import graphviz

# Extract a single tree from the forest
tree = model.estimators_[0]  # Select the first tree (you can change the index)

# Export the tree to a DOT format
dot_data = export_graphviz(tree,
                           feature_names=x_train.columns,  # Use feature names
                           class_names=['1', '2', '3', '5', '6', '7'],  # Use class names
                           filled=True,  # Fill nodes with colors
                           rounded=True,  # Rounded node borders
                           special_characters=True)  # Allow special characters

# Create a graph from the DOT data
graph = graphviz.Source(dot_data)

# Display the graph
graph

# %%
from sklearn.ensemble import BaggingClassifier
bagging=BaggingClassifier(n_estimators=100, max_samples=0.8, max_features=0.8, random_state=42)
bagging.fit(x_train, y_train)
# Out:
# BaggingClassifier(max_features=0.8, max_samples=0.8, n_estimators=100,
#                   random_state=42)

# %%
y_pred_bagging=bagging.predict(x_test)
y_pred_bagging
# Out:
# array([1, 1, 2, 3, 2, 1, 1, 1, 1, 1, 2, 2, 1, 1, 5, 1, 2, 2, 2, 1, 5, 2,
#        2, 2, 1, 2, 1, 5, 7, 1, 2, 6, 2, 2, 7, 2, 5, 1, 6])

# %%
print(f"Accuracy Score: {accuracy_score(y_test, y_pred_bagging)}")
# Out:
# Accuracy Score: 0.7948717948717948

# %%
print(f"Confusion Matrix: \n{confusion_matrix(y_test, y_pred_bagging)}")
# Out:
# Confusion Matrix:
# [[11  2  0  0  0  1]
#  [ 0 12  0  0  0  0]
#  [ 4  1  1  0  0  0]
#  [ 0  0  0  4  0  0]
#  [ 0  0  0  0  2  0]
#  [ 0  0  0  0  0  1]]

# %%
plt.figure(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test, y_pred_bagging), annot=True)
plt.show()

# %%
print(f"Classification Report:\n {classification_report(y_test, y_pred_bagging)}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.73      0.79      0.76        14
#            2       0.80      1.00      0.89        12
#            3       1.00      0.17      0.29         6
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         2
#            7       0.50      1.00      0.67         1
#
#     accuracy                           0.79        39
#    macro avg       0.84      0.83      0.77        39
# weighted avg       0.83      0.79      0.76        39

# %%
df['Type'].value_counts()
# Out:
# Type
# 1    69
# 2    68
# 7    23
# 3    16
# 5     9
# 6     8
# Name: count, dtype: int64

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

base_estimator = DecisionTreeClassifier(max_depth=2)

boosting=AdaBoostClassifier(estimator=base_estimator, n_estimators=200, learning_rate=0.5, random_state=42)
boosting.fit(x_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=2),
#                    learning_rate=0.5, n_estimators=200, random_state=42)

# %%
y_pred_boosting=boosting.predict(x_test)
y_pred_boosting
# Out:
# array([1, 1, 2, 2, 2, 1, 1, 1, 1, 1, 2, 2, 1, 1, 5, 1, 2, 3, 2, 1, 5, 2,
#        2, 2, 1, 2, 1, 5, 1, 1, 2, 6, 1, 2, 7, 2, 5, 1, 6])

# %%
print(f"Accuracy Score: {accuracy_score(y_test, y_pred_boosting)}")
# Out:
# Accuracy Score: 0.7948717948717948

# %%
print(f"Confusion Matrix: \n{confusion_matrix(y_test, y_pred_boosting)}")
# Out:
# Confusion Matrix:
# [[13  1  0  0  0  0]
#  [ 0 11  1  0  0  0]
#  [ 4  2  0  0  0  0]
#  [ 0  0  0  4  0  0]
#  [ 0  0  0  0  2  0]
#  [ 0  0  0  0  0  1]]

# %%
plt.figure(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test, y_pred_boosting), annot=True)
plt.show()

# %%
print(f"Classification Report:\n {classification_report(y_test, y_pred_boosting, zero_division=1)}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.76      0.93      0.84        14
#            2       0.79      0.92      0.85        12
#            3       0.00      0.00      0.00         6
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         1
#
#     accuracy                           0.79        39
#    macro avg       0.76      0.81      0.78        39
# weighted avg       0.70      0.79      0.74        39

# %%
print(f"Random Forest Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"Bagging Accuracy: {accuracy_score(y_test, y_pred_bagging)}")
print(f"Boosting Accuracy: {accuracy_score(y_test, y_pred_boosting)}")
# Out:
# Random Forest Accuracy: 0.7435897435897436
# Bagging Accuracy: 0.7948717948717948
# Boosting Accuracy: 0.7948717948717948

# %% [markdown]
# ___
# ####**Random Forest Accuracy: 0.7435897435897436**
#
# * This indicates that the Random Forest model correctly predicted the glass type for approximately 74.36% of the test data.
#
# #### **Bagging Accuracy: 0.7948717948717948**
#
# * The Bagging model achieved a higher accuracy of around 79.49% on the test data, suggesting that the ensemble approach improved performance compared to the individual Random Forest model.
#
# ####**Boosting Accuracy: 0.7948717948717948**
#
# * The Boosting model also reached an accuracy of 79.49%, similar to the Bagging model. This highlights that the sequential learning and error correction strategy of boosting led to a significant improvement over the base Random Forest.
#
# #### **Inference**
#
# * **Bagging and Boosting Enhanced Performance:** Both Bagging and Boosting outperformed the single Random Forest model, showcasing the benefits of ensemble methods in improving accuracy.
# * **Comparable Results for Bagging and Boosting:** Bagging and Boosting achieved similar accuracy scores, suggesting that both techniques were effective in addressing the challenges of the dataset and improving prediction accuracy.
# * **Ensemble Methods as a Powerful Approach:** The results demonstrate the effectiveness of ensemble methods in enhancing the performance of classification models, potentially reducing overfitting and boosting accuracy.
# * **Further Model Tuning and Evaluation:** While the results are promising, further exploration could involve fine-tuning hyperparameters, experimenting with different ensemble techniques, and using additional evaluation metrics to gain deeper insights into model performance.
#
# ___

# %%
print(f"Random Forest Classification Report:\n {classification_report(y_test, y_pred, zero_division=1)}")
print("___"*40)
print("\n")
print(f"Bagging Classification Report:\n {classification_report(y_test, y_pred_bagging, zero_division=1)}")
print("___"*40)
print("\n")
print(f"Boosting Classification Report:\n {classification_report(y_test, y_pred_boosting, zero_division=1)}")
print("___"*40)
print("\n")
# Out:
# Random Forest Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.67      0.71      0.69        14
#            2       0.69      0.92      0.79        12
#            3       1.00      0.17      0.29         6
#            5       1.00      1.00      1.00         4
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         1
#
#     accuracy                           0.74        39
#    macro avg       0.89      0.80      0.79        39
# weighted avg       0.78      0.74      0.71        39
#
# ________________________________________________________________________________________________________________________
#
#
# Bagging Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.73      0.79      0.76        14
#            2       0.80      1.00      0.89        12
#            3       1.00      0.17      0.29         6
# ...

# %% [markdown]
# _____
#
# ####**Overall Performance**
#
# * **Accuracy:** Both Bagging and Boosting achieved the highest accuracy (79%), outperforming the single Random Forest model (74%). This indicates that ensemble methods enhanced the predictive capability in this case.
# * **Macro Average:** The macro average of precision, recall, and F1-score provides an overall performance overview across all classes. Bagging has a slightly higher macro average (0.84, 0.83, 0.77) compared to Boosting (0.76, 0.81, 0.78) and Random Forest (0.89, 0.80, 0.79). This implies that Bagging had better overall performance.
# * **Weighted Average:** The weighted average considers the class distribution, giving higher importance to classes with more samples. Random Forest (0.78, 0.74, 0.71) had a comparable weighted average of metrics to Bagging (0.83, 0.79, 0.76) and Boosting (0.70, 0.79, 0.74).
#
# ####**Class-Wise Performance**
#
# * **Class 1 and 2:** Boosting showed improved performance for Class 1, with higher precision (0.76), recall (0.93), and F1-score (0.84) compared to Bagging and Random Forest. For Class 2, Bagging achieved better precision (0.80), recall (1.00), and F1-score (0.89).
# * **Class 3:** Random Forest and Bagging achieved higher precision (1.00) for Class 3, but with low recall and F1-score. Boosting had low performance on this class.
# * **Class 5, 6, 7:** All three models performed well on these minority classes, with high precision, recall, and F1-scores.
#
# ####**Inference**
#
# * **Ensemble Advantages:** Bagging and Boosting demonstrate the benefit of ensemble techniques in improving accuracy over a single Random Forest model.
# * **Bagging vs. Boosting:** Bagging shows slightly better overall performance for macro-averaged metrics. Boosting has some advantages for Class 1, but struggled with Class 3.
# * **Class-Specific Performance:** Models vary in performance across different classes. Further analysis is needed to understand why certain classes are more challenging.
# * **Model Selection:** Bagging might be preferred for its balanced performance across most classes. However, model selection should be guided by the specific application context and importance of individual classes.
#
# ####**Additional Observations**
#
# * The recall scores for classes 3 and 7 are 0 or very low for models like Boosting and Random Forest.
# * The precision and recall scores for Class 3 indicate that the model might not have correctly identified all the examples in that class.
# * The models have varying performance across classes. Further investigation and tuning would be beneficial.
#
#
# _________

# %% [markdown]
# ---
# ## **Additional Notes**:
# ### 1. Explain Bagging and Boosting methods. How is it different from each other.
#
# #### Bagging (Bootstrap Aggregating)
# - **Concept**: Bagging involves creating multiple subsets of the original dataset through random sampling with replacement (bootstrapping). Each subset is used to train a base model independently, and the final prediction is determined by combining the predictions of all models.
# - **Process**:
#   - Randomly generate subsets of the data where some instances may be repeated, and others may be excluded.
#   - Train base models (e.g., Decision Trees) on each subset in parallel, independently of one another.
#   - Aggregate predictions, typically by averaging (for regression) or majority voting (for classification).
# - **Benefits**:
#   - Reduces variance and prevents overfitting by averaging out predictions.
#   - Enhances model stability and accuracy.
#   - Particularly effective with unstable models like Decision Trees.
#
# #### Boosting
# - **Concept**: Boosting trains a series of base models sequentially, with each model correcting the errors of the previous one. It assigns weights to data points, emphasizing misclassified instances, and combines predictions using a weighted approach.
# - **Process**:
#   - Train models one after another, adjusting the focus based on errors from prior models.
#   - Increase the weight of misclassified instances so subsequent models prioritize them.
#   - Combine predictions with a weighted average, where better-performing models have greater influence.
# - **Benefits**:
#   - Reduces bias and boosts overall accuracy.
#   - Can outperform Bagging in terms of predictive power.
#   - Effective with weak learners (models slightly better than random guessing).
#
# #### Differences Between Bagging and Boosting
# - **Model Creation**: Bagging trains models independently in parallel; Boosting trains models sequentially.
# - **Data Usage**: Bagging uses random subsets created via bootstrapping; Boosting adjusts weights on the original data.
# - **Prediction**: Bagging aggregates predictions (e.g., averaging or voting); Boosting uses a weighted combination.
# - **Focus**: Bagging reduces variance and overfitting; Boosting reduces bias and improves accuracy.
# - **Model Type**: Bagging suits unstable models; Boosting works well with weak learners.
#
# ---
#
# ### 2. Explain how to handle imbalance in the data.
#
# #### Understanding Data Imbalance
# - Data imbalance occurs when one class in a dataset significantly outnumbers another, leading to models biased toward the majority class and poor performance on the minority class.
#
# #### Techniques to Handle Imbalance
# 1. **Resampling Techniques**:
#    - **Oversampling**: Increase minority class instances by duplicating existing data or generating synthetic examples.
#    - **Undersampling**: Reduce majority class instances by randomly removing some data points.
#    - **Combination**: Apply both oversampling and undersampling to balance the dataset.
#
# 2. **Cost-Sensitive Learning**:
#    - Assign higher penalties for misclassifying the minority class compared to the majority class.
#    - Adjust the model's learning process to prioritize correct classification of the minority class.
#
# 3. **Ensemble Methods**:
#    - Adapt Bagging to create balanced subsets for each base model.
#    - Use Boosting with weighted data to emphasize minority class instances during training.
#
# 4. **Data Augmentation**:
#    - Generate new minority class instances using domain-specific methods (e.g., altering images in image datasets through rotation or cropping).
#
# 5. **Evaluation Metrics**:
#    - Use metrics less affected by imbalance, such as Precision, Recall, and F1-score, to assess performance on the minority class.
#    - Employ AUC (Area Under the ROC Curve) to evaluate overall model performance across thresholds.
#
# #### Choosing the Right Technique
# - The optimal method depends on the dataset and problem context.
# - Experimentation with multiple techniques and evaluation using appropriate metrics is key to identifying the best approach.
# - Consider trade-offs, such as potential overfitting from oversampling or loss of information from undersampling.
#
# ---
