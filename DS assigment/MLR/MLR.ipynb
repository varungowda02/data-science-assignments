# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/DS assigment/MLR/ToyotaCorolla - MLR.csv')
df
# Out:
#       Price  Age_08_04     KM Fuel_Type   HP  Automatic    cc  Doors  \
# 0     13500         23  46986    Diesel   90          0  2000      3
# 1     13750         23  72937    Diesel   90          0  2000      3
# 2     13950         24  41711    Diesel   90          0  2000      3
# 3     14950         26  48000    Diesel   90          0  2000      3
# 4     13750         30  38500    Diesel   90          0  2000      3
# ...     ...        ...    ...       ...  ...        ...   ...    ...
# 1431   7500         69  20544    Petrol   86          0  1300      3
# 1432  10845         72  19000    Petrol   86          0  1300      3
# 1433   8500         71  17016    Petrol   86          0  1300      3
# 1434   7250         70  16916    Petrol   86          0  1300      3
# 1435   6950         76      1    Petrol  110          0  1600      5
#
#       Cylinders  Gears  Weight
# 0             4      5    1165
# 1             4      5    1165
# 2             4      5    1165
# ...

# %%
df.shape
# Out:
# (1436, 11)

# %%
df.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc',
#        'Doors', 'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
df=df.rename(columns={'Age_08_04': 'Age'})

# %%
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'Fuel_Type', 'HP', 'Automatic', 'cc', 'Doors',
#        'Cylinders', 'Gears', 'Weight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
df.describe()
# Out:
#               Price          Age             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %%
df.nunique()
# Out:
# Price         236
# Age            77
# KM           1263
# Fuel_Type       3
# HP             12
# Automatic       2
# cc             13
# Doors           4
# Cylinders       1
# Gears           4
# Weight         59
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Price        0
# Age          0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.isnull().sum()
# Out:
# Price        0
# Age          0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
df.dtypes
# Out:
# Price         int64
# Age           int64
# KM            int64
# Fuel_Type    object
# HP            int64
# Automatic     int64
# cc            int64
# Doors         int64
# Cylinders     int64
# Gears         int64
# Weight        int64
# dtype: object

# %%
df=pd.get_dummies(df,columns=['Fuel_Type'])

# %%
df.dtypes
# Out:
# Price               int64
# Age                 int64
# KM                  int64
# HP                  int64
# Automatic           int64
# cc                  int64
# Doors               int64
# Cylinders           int64
# Gears               int64
# Weight              int64
# Fuel_Type_CNG        bool
# Fuel_Type_Diesel     bool
# Fuel_Type_Petrol     bool
# dtype: object

# %%
for i in df.select_dtypes(include=['bool']).columns:
    df[i]=df[i].astype(int)

# %%
df
# Out:
#       Price  Age     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500   23  46986   90          0  2000      3          4      5
# 1     13750   23  72937   90          0  2000      3          4      5
# 2     13950   24  41711   90          0  2000      3          4      5
# 3     14950   26  48000   90          0  2000      3          4      5
# 4     13750   30  38500   90          0  2000      3          4      5
# ...     ...  ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500   69  20544   86          0  1300      3          4      5
# 1432  10845   72  19000   86          0  1300      3          4      5
# 1433   8500   71  17016   86          0  1300      3          4      5
# 1434   7250   70  16916   86          0  1300      3          4      5
# 1435   6950   76      1  110          0  1600      5          4      5
#
#       Weight  Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %%
df.dtypes
# Out:
# Price               int64
# Age                 int64
# KM                  int64
# HP                  int64
# Automatic           int64
# cc                  int64
# Doors               int64
# Cylinders           int64
# Gears               int64
# Weight              int64
# Fuel_Type_CNG       int64
# Fuel_Type_Diesel    int64
# Fuel_Type_Petrol    int64
# dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df_scaled
# Out:
#          Price       Age        KM        HP  Automatic        cc     Doors  \
# 0     0.325044  0.278481  0.193355  0.170732        0.0  0.047619  0.333333
# 1     0.333925  0.278481  0.300149  0.170732        0.0  0.047619  0.333333
# 2     0.341030  0.291139  0.171647  0.170732        0.0  0.047619  0.333333
# 3     0.376554  0.316456  0.197528  0.170732        0.0  0.047619  0.333333
# 4     0.333925  0.367089  0.158433  0.170732        0.0  0.047619  0.333333
# ...        ...       ...       ...       ...        ...       ...       ...
# 1431  0.111901  0.860759  0.084539  0.138211        0.0  0.000000  0.333333
# 1432  0.230728  0.898734  0.078186  0.138211        0.0  0.000000  0.333333
# 1433  0.147425  0.886076  0.070021  0.138211        0.0  0.000000  0.333333
# 1434  0.103020  0.873418  0.069609  0.138211        0.0  0.000000  0.333333
# 1435  0.092362  0.949367  0.000000  0.333333        0.0  0.020408  1.000000
#
# ...

# %%
df.head()
# Out:
#    Price  Age     KM  HP  Automatic    cc  Doors  Cylinders  Gears  Weight  \
# 0  13500   23  46986  90          0  2000      3          4      5    1165
# 1  13750   23  72937  90          0  2000      3          4      5    1165
# 2  13950   24  41711  90          0  2000      3          4      5    1165
# 3  14950   26  48000  90          0  2000      3          4      5    1165
# 4  13750   30  38500  90          0  2000      3          4      5    1170
#
#    Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0              0                 1                 0
# 1              0                 1                 0
# 2              0                 1                 0
# 3              0                 1                 0
# 4              0                 1                 0

# %%
df.nunique()
# Out:
# Price                236
# Age                   77
# KM                  1263
# HP                    12
# Automatic              2
# cc                    13
# Doors                  4
# Cylinders              1
# Gears                  4
# Weight                59
# Fuel_Type_CNG          2
# Fuel_Type_Diesel       2
# Fuel_Type_Petrol       2
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms for all columns
for col in df.columns:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], bins=30, kde=True)  # Add KDE for better visualization
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
df['Cylinders'].unique()
# Out:
# array([4])

# %%
df['Gears'].unique()
# Out:
# array([5, 6, 3, 4])

# %%
df.drop('Cylinders', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'HP', 'Automatic', 'cc', 'Doors', 'Gears',
#        'Weight', 'Fuel_Type_CNG', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol'],
#       dtype='object')

# %%
for i in df.columns:
  plt.figure(figsize=(8,5))
  sns.boxplot(df[i])
  plt.show()

# %%
z=df.corr()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(z, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df, diag_kind='kde')

# %%
z
# Out:
#                      Price       Age        KM        HP  Automatic        cc  \
# Price             1.000000 -0.876590 -0.569960  0.314990   0.033081  0.126389
# Age              -0.876590  1.000000  0.505672 -0.156622   0.031717 -0.098084
# KM               -0.569960  0.505672  1.000000 -0.333538  -0.081854  0.102683
# HP                0.314990 -0.156622 -0.333538  1.000000   0.013144  0.035856
# Automatic         0.033081  0.031717 -0.081854  0.013144   1.000000  0.066740
# cc                0.126389 -0.098084  0.102683  0.035856   0.066740  1.000000
# Doors             0.185326 -0.148359 -0.036197  0.092424  -0.027654  0.079903
# Gears             0.063104 -0.005364  0.015023  0.209477  -0.098555  0.014629
# Weight            0.581198 -0.470253 -0.028598  0.089614   0.057249  0.335637
# Fuel_Type_CNG    -0.039536  0.002389  0.144016  0.062109   0.001486  0.005941
# Fuel_Type_Diesel  0.054084 -0.097740  0.403060 -0.533453  -0.084490  0.327723
# ...

# %%
df.describe()
# Out:
#               Price          Age             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors        Gears      Weight  Fuel_Type_CNG  \
# count   1436.00000  1436.000000  1436.000000  1436.00000    1436.000000
# mean    1576.85585     4.033426     5.026462  1072.45961       0.011838
# std      424.38677     0.952677     0.188510    52.64112       0.108196
# ...

# %%
from scipy.stats import skew, kurtosis
q1=df.quantile(0.25)
q3=df.quantile(0.75)
iqr=q3-q1
upper_bound=q3-1.5*iqr
lower_bound=q1-1.5*iqr

for i in df.columns:
  print(f"Interquertile Range of {i}: {iqr[i]}")
  print(f"Upper Bound of {i}: {upper_bound[i]}")
  print(f"Lower Bound of {i}: {lower_bound[i]}")
  print(f"Skewness of {i}: {skew(df[i])}")
  print(f"Kurtosis of {i}: {kurtosis(df[i])}\n")
# Out:
# Interquertile Range of Price: 3500.0
# Upper Bound of Price: 6700.0
# Lower Bound of Price: 3200.0
# Skewness of Price: 1.702104639170028
# Kurtosis of Price: 3.720603948160326
#
# Interquertile Range of Age: 26.0
# Upper Bound of Age: 31.0
# Lower Bound of Age: 5.0
# Skewness of Age: -0.8258380758865862
# Kurtosis of Age: -0.08054127692213431
#
# Interquertile Range of KM: 44020.75
# Upper Bound of KM: 20989.625
# Lower Bound of KM: -23031.125
# Skewness of KM: 1.0148507004031242
# Kurtosis of KM: 1.675019881452977
#
# Interquertile Range of HP: 20.0
# Upper Bound of HP: 80.0
# Lower Bound of HP: 60.0
# Skewness of HP: 0.9548369218420583
# Kurtosis of HP: 8.801520963566196
#
# Interquertile Range of Automatic: 0.0
# Upper Bound of Automatic: 0.0
# Lower Bound of Automatic: 0.0
# Skewness of Automatic: 3.874144686269151
# Kurtosis of Automatic: 13.008997050147496
#
# Interquertile Range of cc: 200.0
# Upper Bound of cc: 1300.0
# Lower Bound of cc: 1100.0
# ...

# %%
df.head()
# Out:
#    Price  Age     KM  HP  Automatic    cc  Doors  Gears  Weight  \
# 0  13500   23  46986  90          0  2000      3      5    1165
# 1  13750   23  72937  90          0  2000      3      5    1165
# 2  13950   24  41711  90          0  2000      3      5    1165
# 3  14950   26  48000  90          0  2000      3      5    1165
# 4  13750   30  38500  90          0  2000      3      5    1170
#
#    Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol
# 0              0                 1                 0
# 1              0                 1                 0
# 2              0                 1                 0
# 3              0                 1                 0
# 4              0                 1                 0

# %%
x=df.drop('Price', axis=1)
x
# Out:
#       Age     KM   HP  Automatic    cc  Doors  Gears  Weight  Fuel_Type_CNG  \
# 0      23  46986   90          0  2000      3      5    1165              0
# 1      23  72937   90          0  2000      3      5    1165              0
# 2      24  41711   90          0  2000      3      5    1165              0
# 3      26  48000   90          0  2000      3      5    1165              0
# 4      30  38500   90          0  2000      3      5    1170              0
# ...   ...    ...  ...        ...   ...    ...    ...     ...            ...
# 1431   69  20544   86          0  1300      3      5    1025              0
# 1432   72  19000   86          0  1300      3      5    1015              0
# 1433   71  17016   86          0  1300      3      5    1015              0
# 1434   70  16916   86          0  1300      3      5    1015              0
# 1435   76      1  110          0  1600      5      5    1114              0
#
#       Fuel_Type_Diesel  Fuel_Type_Petrol
# ...

# %%
y=df['Price']
y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1436, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.80, random_state=42)

# %%
print(f"Training size of x:{x_train.shape} and y:{y_train.shape}")
print(f"Test size of x:{x_test.shape} and y:{y_test.shape} \n")
# Out:
# Training size of x:(1148, 11) and y:(1148,)
# Test size of x:(288, 11) and y:(288,)

# %%
from statsmodels.formula.api import ols

# %%
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'HP', 'Automatic', 'cc', 'Doors', 'Gears',
#        'Weight', 'Fuel_Type_CNG', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol'],
#       dtype='object')

# %%
ols_formula1 = "Price ~ Age + KM + HP + Automatic + cc + Doors + Gears + Weight + Fuel_Type_CNG + Fuel_Type_Diesel + Fuel_Type_Petrol"
model1=ols(formula=ols_formula1, data=df).fit()

# %%
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.864
# Method:                 Least Squares   F-statistic:                     912.3
# Date:                Sat, 29 Mar 2025   Prob (F-statistic):               0.00
# Time:                        06:59:41   Log-Likelihood:                -12369.
# No. Observations:                1436   AIC:                         2.476e+04
# Df Residuals:                    1425   BIC:                         2.482e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -6971.2342   1143.563     -6.096      0.000   -9214.482   -4727.986
# ...

# %%
print("Coefficient:\n",model1.params)
# Out:
# Coefficient:
#  Intercept          -6971.234151
# Age                 -123.777069
# KM                    -0.017523
# HP                    23.526963
# Automatic            300.259212
# cc                    -0.055629
# Doors                -30.356710
# Gears                622.798964
# Weight                20.817390
# Fuel_Type_CNG      -2889.795047
# Fuel_Type_Diesel   -2335.740703
# Fuel_Type_Petrol   -1745.698402
# dtype: float64

# %%
print("R-squared:", model1.rsquared)
# Out:
# R-squared: 0.8649083778053923

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot regression plot for Model 1
plt.figure(figsize=(16, 8))
sns.regplot(x=df["Price"], y=model1.fittedvalues, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("OLS Model 1 - Regression Plot")

plt.show()

# %%
print(model1.pvalues)
# Out:
# Intercept            1.397126e-09
# Age                 2.563202e-292
# KM                   2.205339e-37
# HP                   6.531756e-11
# Automatic            6.243429e-02
# cc                   5.457514e-01
# Doors                4.581674e-01
# Gears                1.694943e-03
# Weight               1.041115e-59
# Fuel_Type_CNG        3.690245e-11
# Fuel_Type_Diesel     1.099410e-06
# Fuel_Type_Petrol     9.631372e-07
# dtype: float64

# %%
alpha = 0.05
print("Significant")
for i,j in model1.pvalues.items():
  if j < alpha:
    print(f"{i}: {j}")

print("\nNot Significant")
for i,j in model1.pvalues.items():
  if j >= alpha:
    print(f"{i}: {j}")
# Out:
# Significant
# Intercept: 1.3971257298473286e-09
# Age: 2.5632022012500896e-292
# KM: 2.205339215142678e-37
# HP: 6.531755986630642e-11
# Gears: 0.001694943134534983
# Weight: 1.0411148305011239e-59
# Fuel_Type_CNG: 3.690245268359461e-11
# Fuel_Type_Diesel: 1.0994103205294438e-06
# Fuel_Type_Petrol: 9.63137196332736e-07
#
# Not Significant
# Automatic: 0.06243429191368785
# cc: 0.5457513595773511
# Doors: 0.4581673751753458

# %%
ols_formula2= "Price ~ Age + KM + HP + Gears + Weight + Fuel_Type_CNG + Fuel_Type_Diesel + Fuel_Type_Petrol"
model2 = ols(formula=ols_formula2, data=df).fit()

# %%
print(model2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.864
# Method:                 Least Squares   F-statistic:                     1301.
# Date:                Sat, 29 Mar 2025   Prob (F-statistic):               0.00
# Time:                        06:59:42   Log-Likelihood:                -12372.
# No. Observations:                1436   AIC:                         2.476e+04
# Df Residuals:                    1428   BIC:                         2.480e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept        -7145.5449   1136.709     -6.286      0.000   -9375.344   -4915.746
# ...

# %%
print("R Square: ", model2.rsquared)
# Out:
# R Square:  0.8644748583146363

# %%
plt.figure(figsize=(16,8))
sns.regplot(x=df['Price'], y=model2.fittedvalues, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("OLS Model 2 - Regression Plot")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model3_train=LinearRegression()
model3_train.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train=model3_train.predict(x_train)
print(y_pred_train)
# Out:
# [ 9076.78487228  8703.05493339 13562.76268609 ...  7933.64609318
#   8600.7335279   6466.96975655]

# %%
from sklearn.metrics import r2_score
model3_score_train=r2_score(y_train, y_pred_train)
print("R Squared Value of train: ", model3_score_train)
# Out:
# R Squared Value of train:  0.8702643169608926

# %%
plt.figure(figsize=(16, 8))
sns.regplot(x=y_train, y=model3_train.predict(x_train), scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("MLR Train")
plt.show()

# %%
model3_test=LinearRegression()
model3_test.fit(x_test, y_test)
# Out:
# LinearRegression()

# %%
y_pred_test=model3_test.predict(x_test)
print(y_pred_test)
# Out:
# [11768.33910244  8717.61152558  9019.05672347  8664.06559494
#   9793.14508634  7371.25659452  8711.27485011  8124.61892432
#  13881.28217845 12863.96040723  8924.91377355  9138.05221943
#  12723.63078108 13590.72327062  9548.87646433  8636.30890613
#  12808.03459759 17385.39800341  7115.81472171  8898.01200717
#  12784.70668601 17367.62671521  7647.31961764 10952.83827346
#   7662.32108196 15403.03964787 10138.04872466  7069.34645883
#  15381.03303267 14334.16344147  7950.34056522  9926.66121515
#   8219.75974004  9970.80845344 10147.2820304   7786.66591968
#   8889.94156156  9833.00361212 16098.49213288  9178.07269552
#   9734.67591436  9385.89949129  7559.67731092  5721.29105112
#   7128.81014479 16362.44457952  9289.5434695  10385.80418015
#   9124.73184177 13237.66121422 12917.57106224  6664.21852965
#  14590.58527883 15500.6290701   6295.4839334   7411.73610524
#  10464.48546553 10545.81193878 15274.42082634 22194.4085004
# ...

# %%
model3_score_test=r2_score(y_test, y_pred_test)
print("R Squared Value of Test: ", model3_score_test)
# Out:
# R Squared Value of Test:  0.8750007618807176

# %%
plt.figure(figsize=(16, 8))
sns.regplot(x=y_train, y=model3_test.predict(x_train), scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("MLR Test")
plt.show()

# %%
import numpy as np

# %%
alphas = np.random.uniform(low=0, high=1, size=(50,))

# %%
from sklearn.linear_model import LassoCV
lasso_cv_train = LassoCV(alphas=alphas, cv=5)
lasso_cv_train.fit(x_train, y_train)
# Out:
# LassoCV(alphas=array([0.04331312, 0.51238041, 0.95227225, 0.31036007, 0.73566329,
#        0.20906653, 0.13115906, 0.34829623, 0.97819301, 0.88749609,
#        0.0230924 , 0.38547724, 0.73922937, 0.9796841 , 0.3697522 ,
#        0.36316589, 0.12100333, 0.51164336, 0.59433567, 0.15588299,
#        0.26311298, 0.21743199, 0.14074861, 0.39440153, 0.39951408,
#        0.89532929, 0.67701307, 0.11122619, 0.39943126, 0.33700495,
#        0.27042625, 0.76109197, 0.45627443, 0.7599665 , 0.0103406 ,
#        0.81426874, 0.23075364, 0.63234698, 0.46672404, 0.77954269,
#        0.14696885, 0.0491955 , 0.35578533, 0.50944126, 0.91253983,
#        0.15809125, 0.92702983, 0.36319225, 0.5647292 , 0.75603398]),
#         cv=5)

# %%
# Get the best alpha
best_alpha_lasso_train = lasso_cv_train.alpha_
print(f"Best Alpha Train: {best_alpha_lasso_train}")
# Out:
# Best Alpha Train: 0.979684100800397

# %%
from sklearn.linear_model import Lasso
# Train Lasso with the best alpha
lasso_train = Lasso(alpha=best_alpha_lasso_train)
lasso_train.fit(x_train, y_train)
# Out:
# Lasso(alpha=np.float64(0.979684100800397))

# %%
y_pred_lasso_train=lasso_train.predict(x_train)
print(y_pred_lasso_train)
# Out:
# [ 9075.09454345  8711.3658035  13566.71586045 ...  7937.41580777
#   8597.76366502  6471.19585935]

# %%
lasso_score_train = r2_score(y_train, y_pred_lasso_train)
print("R Squared values for Traning (Lasso): ", lasso_score_train)
# Out:
# R Squared values for Traning (Lasso):  0.8702578062804094

# %%
plt.figure(figsize=(16, 8))
sns.regplot(x=y_train, y=lasso_train.predict(x_train), scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Lasso Train")
plt.show()

# %%
lasso_cv_test = LassoCV(alphas=alphas, cv=5)
lasso_cv_test.fit(x_test, y_test)
# Out:
# LassoCV(alphas=array([0.04331312, 0.51238041, 0.95227225, 0.31036007, 0.73566329,
#        0.20906653, 0.13115906, 0.34829623, 0.97819301, 0.88749609,
#        0.0230924 , 0.38547724, 0.73922937, 0.9796841 , 0.3697522 ,
#        0.36316589, 0.12100333, 0.51164336, 0.59433567, 0.15588299,
#        0.26311298, 0.21743199, 0.14074861, 0.39440153, 0.39951408,
#        0.89532929, 0.67701307, 0.11122619, 0.39943126, 0.33700495,
#        0.27042625, 0.76109197, 0.45627443, 0.7599665 , 0.0103406 ,
#        0.81426874, 0.23075364, 0.63234698, 0.46672404, 0.77954269,
#        0.14696885, 0.0491955 , 0.35578533, 0.50944126, 0.91253983,
#        0.15809125, 0.92702983, 0.36319225, 0.5647292 , 0.75603398]),
#         cv=5)

# %%
best_alpha_lasso_test=lasso_cv_test.alpha_
print(f"Best Alpha Test: {best_alpha_lasso_test}")
# Out:
# Best Alpha Test: 0.010340603160437722

# %%
lasso_test = Lasso(alpha=best_alpha_lasso_test)
lasso_test.fit(x_test, y_test)
# Out:
# Lasso(alpha=np.float64(0.010340603160437722))

# %%
y_pred_lasso_test=lasso_test.predict(x_test)
print(y_pred_lasso_test)
# Out:
# [11768.2987264   8717.72795499  9019.03144671  8664.08238012
#   9793.16877154  7371.28863182  8711.31672584  8124.7013172
#  13881.35649151 12864.0139544   8924.97255898  9138.15591644
#  12723.6856422  13590.70947092  9549.0058769   8636.25790928
#  12808.02015376 17385.27058927  7115.94401758  8898.02170764
#  12784.83286755 17367.79598788  7647.41394957 10952.80078977
#   7662.20125078 15403.15677418 10137.68829385  7069.47171096
#  15381.03567364 14334.22403971  7950.44458875  9926.63556738
#   8219.76817648  9970.92760369 10147.39583641  7786.77238461
#   8889.98054188  9833.12148461 16098.50575249  9178.13136014
#   9734.78041166  9386.00364882  7559.6839331   5721.2738215
#   7128.75029061 16362.60687045  9289.65599599 10385.84807432
#   9124.67695571 13237.7088954  12917.70202736  6664.14549009
#  14590.60095538 15500.85624974  6295.45476619  7411.75265855
#  10464.53127284 10545.42721206 15274.55610581 22193.42153273
# ...

# %%
lasso_score_test = r2_score(y_test, y_pred_lasso_test)
print("R Squared values for Test (Lasso): ", lasso_score_test)
# Out:
# R Squared values for Test (Lasso):  0.8750007602576477

# %%
plt.figure(figsize=(16, 8))
sns.regplot(x=y_test, y=lasso_test.predict(x_test), scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Lasso Test")
plt.show()

# %%
from sklearn.linear_model import RidgeCV
ridge_cv_train=RidgeCV(alphas=alphas, cv=5)
ridge_cv_train.fit(x_train, y_train)
# Out:
# RidgeCV(alphas=array([0.04331312, 0.51238041, 0.95227225, 0.31036007, 0.73566329,
#        0.20906653, 0.13115906, 0.34829623, 0.97819301, 0.88749609,
#        0.0230924 , 0.38547724, 0.73922937, 0.9796841 , 0.3697522 ,
#        0.36316589, 0.12100333, 0.51164336, 0.59433567, 0.15588299,
#        0.26311298, 0.21743199, 0.14074861, 0.39440153, 0.39951408,
#        0.89532929, 0.67701307, 0.11122619, 0.39943126, 0.33700495,
#        0.27042625, 0.76109197, 0.45627443, 0.7599665 , 0.0103406 ,
#        0.81426874, 0.23075364, 0.63234698, 0.46672404, 0.77954269,
#        0.14696885, 0.0491955 , 0.35578533, 0.50944126, 0.91253983,
#        0.15809125, 0.92702983, 0.36319225, 0.5647292 , 0.75603398]),
#         cv=5)

# %%
best_alpha_ridge_train=ridge_cv_train.alpha_
print(f"Best Alpha Train: {best_alpha_ridge_train}")
# Out:
# Best Alpha Train: 0.979684100800397

# %%
from sklearn.linear_model import Ridge
ridge_train=Ridge(alpha=best_alpha_ridge_train)
ridge_train.fit(x_train, y_train)
# Out:
# Ridge(alpha=np.float64(0.979684100800397))

# %%
y_pred_ridge_train=ridge_train.predict(x_train)
print(y_pred_ridge_train)
# Out:
# [ 9075.41675342  8706.67716962 13563.84493653 ...  7934.04089146
#   8599.22772741  6467.55156685]

# %%
ridge_score_train=r2_score(y_train, y_pred_ridge_train)
print("R Squared Value of Train (Ridge): ", ridge_score_train)
# Out:
# R Squared Value of Train (Ridge):  0.8702623153502496

# %%
plt.figure(figsize=(16, 8))
sns.regplot(x=y_train, y=ridge_train.predict(x_train), scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Ridge Train")
plt.show()

# %%
ridge_cv_test=RidgeCV(alphas=alphas, cv=5)
ridge_cv_test.fit(x_test, y_test)
# Out:
# RidgeCV(alphas=array([0.04331312, 0.51238041, 0.95227225, 0.31036007, 0.73566329,
#        0.20906653, 0.13115906, 0.34829623, 0.97819301, 0.88749609,
#        0.0230924 , 0.38547724, 0.73922937, 0.9796841 , 0.3697522 ,
#        0.36316589, 0.12100333, 0.51164336, 0.59433567, 0.15588299,
#        0.26311298, 0.21743199, 0.14074861, 0.39440153, 0.39951408,
#        0.89532929, 0.67701307, 0.11122619, 0.39943126, 0.33700495,
#        0.27042625, 0.76109197, 0.45627443, 0.7599665 , 0.0103406 ,
#        0.81426874, 0.23075364, 0.63234698, 0.46672404, 0.77954269,
#        0.14696885, 0.0491955 , 0.35578533, 0.50944126, 0.91253983,
#        0.15809125, 0.92702983, 0.36319225, 0.5647292 , 0.75603398]),
#         cv=5)

# %%
best_alpha_ridge_test=ridge_cv_test.alpha_
print(f"Best Alpha Test: {best_alpha_ridge_test}")
# Out:
# Best Alpha Test: 0.979684100800397

# %%
ridge_test = Ridge(alpha=best_alpha_ridge_test)
ridge_test.fit(x_test, y_test)
# Out:
# Ridge(alpha=np.float64(0.979684100800397))

# %%
ridge_score_test=r2_score(y_test, ridge_test.predict(x_test))
print("R Squared Value of Test (Ridge): ", ridge_score_test)
# Out:
# R Squared Value of Test (Ridge):  0.8743181844924915

# %%
plt.figure(figsize=(16, 8))
sns.regplot(x=y_test, y=ridge_test.predict(x_test), scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Ridge Test")
plt.show()

# %%
import pandas as pd

# Create a DataFrame
r2_table = pd.DataFrame({
    "Model": [
        "OLS Model 1",
        "OLS Model 2",
        "MLR (Train)", "MLR (Test)",
        "Lasso (Train)", "Lasso (Test)",
        "Ridge (Train)", "Ridge (Test)"
    ],
    "R² Value": [
        model1.rsquared,
        model2.rsquared,
        model3_score_train, model3_score_test,
        lasso_score_train, lasso_score_test,
        ridge_score_train, ridge_score_test
    ]
})

# Print the table
r2_table
# Out:
#            Model  R² Value
# 0    OLS Model 1  0.864908
# 1    OLS Model 2  0.864475
# 2    MLR (Train)  0.870264
# 3     MLR (Test)  0.875001
# 4  Lasso (Train)  0.870258
# 5   Lasso (Test)  0.875001
# 6  Ridge (Train)  0.870262
# 7   Ridge (Test)  0.874318

# %%
print(r2_table.max())
# Out:
# Model       Ridge (Train)
# R² Value         0.875001
# dtype: object

# %%
print(r2_table.min())
# Out:
# Model       Lasso (Test)
# R² Value        0.864475
# dtype: object

# %% [markdown]
# # **Interview Questions**
#
# ### 1. **Normalization & Standardization**
# Normalization and standardization are techniques used to scale numerical data to improve the performance of machine learning algorithms.
#
# #### **Normalization**
# Normalization rescales the data to a fixed range, typically \([0,1]\) or \([-1,1]\). This ensures that all features contribute equally to the model.
# The **Min-Max Scaling** formula is:
#
# $$
# X' = \frac{X - X_{min}}{X_{max} - X_{min}}
# $$
#
# where:
# - $X$ is the original value
# - $X_{min}$ and $X_{max}$ are the minimum and maximum values in the feature
#
# **Use case:** Normalization is preferred when the data does not follow a Gaussian (normal) distribution or when using models like KNN and Neural Networks.
#
# #### **Standardization**
# Standardization transforms the data to have a mean of 0 and a standard deviation of 1. It maintains the original distribution of the data.
# The **Z-score Scaling** formula is:
#
# $$
# X' = \frac{X - \mu}{\sigma}
# $$
#
# where:
# - $\mu$ is the mean of the feature
# - $\sigma$ is the standard deviation
#
# **Use case:** Standardization is used when data follows a normal distribution or when applying models like logistic regression, SVM, and PCA.
#
# ---
#
# ### 2. **Techniques to Address Multicollinearity in Multiple Linear Regression**
# Multicollinearity occurs when independent variables are highly correlated, affecting model interpretability.
#
# #### **Methods to Handle Multicollinearity:**
#
# 1. **Variance Inflation Factor (VIF):**
#    - VIF quantifies the level of multicollinearity by measuring how much the variance of a regression coefficient is inflated.
#    - Formula:
#
#    $$
#    VIF = \frac{1}{1 - R^2}
#    $$
#
#    - If \(VIF > 10\), multicollinearity is high, and the variable should be removed or transformed.
#
# 2. **Removing Highly Correlated Features:**
#    - Compute the correlation matrix and drop one of the highly correlated features.
#
# 3. **Principal Component Analysis (PCA):**
#    - PCA transforms correlated variables into a set of uncorrelated principal components.
#
# 4. **Regularization (Ridge or Lasso Regression):**
#    - **Ridge Regression:** Uses L2 regularization, which shrinks coefficients but keeps all features.
#    - **Lasso Regression:** Uses L1 regularization, which can eliminate some coefficients, making the model sparse.
#    - Ridge regression formula:
#
#      $$
#      \beta = (X^T X + \lambda I)^{-1} X^T Y
#      $$
#
#      where $\lambda$ is the regularization parameter.
#
# These techniques help improve model stability, interpretation, and predictive performance.

# %% [markdown]
# ### **Regularization Techniques: Ridge & Lasso Regression**
# Regularization methods introduce a penalty to the regression model, preventing overfitting and reducing the impact of multicollinearity.
#
# ---
#
# ## **Ridge Regression (L2 Regularization)**
# Ridge regression adds an L2 penalty, which shrinks the regression coefficients but does not eliminate any features.
# The cost function is modified as:
#
# $$
# J(\beta) = \sum_{i=1}^{n} (y_i - \hat{y}_i)^2 + \lambda \sum_{j=1}^{p} \beta_j^2
# $$
#
# where:
# - $J(\beta)$ is the cost function
# - $y_i$ is the actual value
# - $\hat{y}_i$ is the predicted value
# - $\beta_j$ are the regression coefficients
# - $\lambda$ is the regularization parameter
#
# ### **Impact of Ridge Regression:**
# - Reduces the effect of correlated variables without eliminating them.
# - Works well when all features contribute to the prediction.
#
# ---
#
# ## **Lasso Regression (L1 Regularization)**
# Lasso regression adds an L1 penalty, which can shrink some coefficients to zero, effectively performing feature selection.
# The cost function is:
#
# $$
# J(\beta) = \sum_{i=1}^{n} (y_i - \hat{y}_i)^2 + \lambda \sum_{j=1}^{p} |\beta_j|
# $$
#
# ### **Impact of Lasso Regression:**
# - Removes irrelevant features by setting some coefficients to zero.
# - Helps in feature selection while addressing multicollinearity.
#
# ---
#
# ## **Choosing Between Ridge & Lasso:**
# - **Use Ridge** if all features are important but highly correlated.
# - **Use Lasso** if feature selection is needed to reduce complexity.
# - **Elastic Net** is a combination of both Ridge and Lasso for better performance.
