# %%
import pandas as pd
df=pd.read_excel("/content/drive/MyDrive/DS assigment/Clustering/EastWestAirlines.xlsx", sheet_name='data')
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.rename(columns={'ID#': 'ID', 'Award?': 'Award'}, inplace=True)
df
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.set_index('ID', inplace=True)
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID
# ...

# %%
df.columns
# Out:
# Index(['Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3999 entries, 1 to 4021
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award              3999 non-null   int64
# dtypes: int64(11)
# memory usage: 374.9 KB

# %%
df.shape
# Out:
# (3999, 11)

# %%
df.dtypes
# Out:
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award                int64
# dtype: object

# %%
df.nunique()
# Out:
# Balance              3904
# Qual_miles            164
# cc1_miles               5
# cc2_miles               3
# cc3_miles               5
# Bonus_miles          2734
# Bonus_trans            57
# Flight_miles_12mo     343
# Flight_trans_12        35
# Days_since_enroll    2820
# Award                   2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 3899     1000           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID
# 3899            0                  0                0               1597
#
#       Award
# ID
# 3899      0

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award]
# Index: []

# %%
df.shape
# Out:
# (3998, 11)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# for i in df.columns:
#   plt.figure(figsize=(20,4))
#   sns.boxplot(x=df[i])
#   plt.title(f"Boxplot of {i}")
# plt.tight_layout()
# plt.show()

# %%
import numpy as np

# %%
threshold=3
z_score=np.abs((df-df.mean())/df.std())
df=df[(z_score<threshold).all(axis=1)]

# %%
df.shape
# Out:
# (3630, 11)

# %%
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Selecting only continuous numerical columns
cols_to_scale = ["Balance", "Qual_miles", "Bonus_miles", "Bonus_trans", "Flight_miles_12mo", "Flight_trans_12", "Days_since_enroll"]
df.loc[:, cols_to_scale] = scaler.fit_transform(df[cols_to_scale]).astype('float64')
# Out:
# <ipython-input-21-021c8a9aff00>:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.52312784 -0.66645791 -0.31034735 ...  0.20896848 -0.09218735
#  -0.92783114]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, cols_to_scale] = scaler.fit_transform(df[cols_to_scale]).astype('float64')
# <ipython-input-21-021c8a9aff00>:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-0.15886912 -0.15886912 -0.15886912 ... -0.15886912 -0.15886912
#  -0.15886912]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, cols_to_scale] = scaler.fit_transform(df[cols_to_scale]).astype('float64')
# ...

# %%
df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID
# 1    -0.523128   -0.158869          1          1          1    -0.779368
# 2    -0.666458   -0.158869          1          1          1    -0.777106
# 3    -0.310347   -0.158869          1          1          1    -0.561556
# 4    -0.738421   -0.158869          1          1          1    -0.761387
# 5     0.598016   -0.158869          4          1          1     1.599298
# ...        ...         ...        ...        ...        ...          ...
# 4017 -0.678828   -0.158869          1          1          1    -0.318758
# 4018  0.060597   -0.158869          1          1          1    -0.734857
# 4019  0.208968   -0.158869          3          1          1     0.614595
# 4020 -0.092187   -0.158869          1          1          1    -0.761387
# 4021 -0.927831   -0.158869          1          1          1    -0.788965
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID
# ...

# %%
# for i in df.columns:
#   plt.figure(figsize=(10,5))
#   sns.distplot(df[i])
#   plt.title(f"Distibution of {i}")
# plt.show()

# %%
# for i in df.columns:
#   plt.figure(figsize=(10,5))
#   sns.histplot(df[i], bins=30, kde=True)
#   plt.title(f"Histogram of {i}")
# plt.show()

# %%
from scipy.stats import skew, kurtosis
for i in df.columns:
  print(f"Skewness of {i}: {df[i].skew()}")
  print(f"Kurtosis of {i}: {df[i].kurtosis()} \n")
# Out:
# Skewness of Balance: 1.8878820183964098
# Kurtosis of Balance: 4.091813460062424
#
# Skewness of Qual_miles: 7.077248392488803
# Kurtosis of Qual_miles: 52.89444822802532
#
# Skewness of cc1_miles: 0.8990563776947681
# Kurtosis of cc1_miles: -0.6444124653417451
#
# Skewness of cc2_miles: 0.0
# Kurtosis of cc2_miles: 0.0
#
# Skewness of cc3_miles: 0.0
# Kurtosis of cc3_miles: 0.0
#
# Skewness of Bonus_miles: 1.5738548173605522
# Kurtosis of Bonus_miles: 1.8772016960108315
#
# Skewness of Bonus_trans: 0.6127004231479778
# Kurtosis of Bonus_trans: 0.02374880811490465
#
# Skewness of Flight_miles_12mo: 3.5694766098273916
# Kurtosis of Flight_miles_12mo: 14.37203757401424
#
# Skewness of Flight_trans_12: 3.2819629180779115
# Kurtosis of Flight_trans_12: 12.075679549968696
#
# Skewness of Days_since_enroll: 0.14150071269884543
# Kurtosis of Days_since_enroll: -0.947347623443286
#
# Skewness of Award: 0.6734676964804664
# Kurtosis of Award: -1.5472940691913433

# %%
# for i in df.columns:
#   plt.figure(figsize=(10,5))
#   print(f"{i}")
#   sns.kdeplot(df[i])
# plt.show()

# %%
df.drop(['cc2_miles', 'cc3_miles'], axis=1, inplace=True)
# Out:
# <ipython-input-27-8148186180b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['cc2_miles', 'cc3_miles'], axis=1, inplace=True)

# %%
df
# Out:
#        Balance  Qual_miles  cc1_miles  Bonus_miles  Bonus_trans  \
# ID
# 1    -0.523128   -0.158869          1    -0.779368    -1.147512
# 2    -0.666458   -0.158869          1    -0.777106    -1.026370
# 3    -0.310347   -0.158869          1    -0.561556    -0.784086
# 4    -0.738421   -0.158869          1    -0.761387    -1.147512
# 5     0.598016   -0.158869          4     1.599298     1.881039
# ...        ...         ...        ...          ...          ...
# 4017 -0.678828   -0.158869          1    -0.318758    -0.784086
# 4018  0.060597   -0.158869          1    -0.734857    -0.662944
# 4019  0.208968   -0.158869          3     0.614595    -0.299518
# 4020 -0.092187   -0.158869          1    -0.761387    -1.147512
# 4021 -0.927831   -0.158869          1    -0.788965    -1.268654
#
#       Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# ID
# 1             -0.402210        -0.432152           1.431060      0
# ...

# %%
# sns.pairplot(df)
# plt.show

# %%
z=df.corr()
z
# Out:
#                     Balance  Qual_miles  cc1_miles  Bonus_miles  Bonus_trans  \
# Balance            1.000000    0.061626   0.422605     0.457206     0.355819
# Qual_miles         0.061626    1.000000   0.003091     0.024523     0.028937
# cc1_miles          0.422605    0.003091   1.000000     0.912316     0.648392
# Bonus_miles        0.457206    0.024523   0.912316     1.000000     0.631836
# Bonus_trans        0.355819    0.028937   0.648392     0.631836     1.000000
# Flight_miles_12mo  0.196775    0.101695   0.030035     0.113353     0.193163
# Flight_trans_12    0.200089    0.109105   0.027328     0.114848     0.218694
# Days_since_enroll  0.252751    0.017641   0.209202     0.194642     0.147474
# Award              0.105302    0.092326   0.325591     0.366642     0.289096
#
#                    Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# Balance                     0.196775         0.200089           0.252751
# ...

# %%
sns.heatmap(z, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1, 11):
  kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
  kmeans.fit(df)
  wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [32546.12479338847,
#  22686.260702040476,
#  18236.465518328074,
#  16438.394248884128,
#  13812.044761585172,
#  12361.944144941901,
#  11675.491184873334,
#  11079.468761376758,
#  10477.872348041954,
#  9736.15397525216]

# %%
plt.plot(range(1,11), wcss, marker="*")
plt.title("The Elbow Method")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("WCSS")
plt.show()

# %%
from sklearn.metrics import silhouette_score

silhouette_scores = []
for i in range(2, 11):  # Silhouette score is not defined for k=1
    kmeans = KMeans(n_clusters=i, random_state=42)
    labels = kmeans.fit_predict(df)
    silhouette_scores.append(silhouette_score(df, labels))

# Plot the silhouette scores
plt.plot(range(2, 11), silhouette_scores, marker='o')
plt.title('Silhouette Method')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.show()

# Interpretation:
# Choose the k value that maximizes the silhouette score.
# Higher silhouette scores indicate better-defined clusters.

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=42)
kmeans.fit(df)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
wcss=kmeans.inertia_
wcss
# Out:
# 18236.465518328074

# %%
kmlabels=kmeans.labels_
kmlabels
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int32)

# %%
silhouette_score(df, kmlabels)
# Out:
# np.float64(0.37504881877643975)

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
hc=AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')
hc.fit(df)
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
hclabels=hc.labels_
silhouette_score(df, hclabels)
# Out:
# np.float64(0.29665221644571116)

# %%
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import numpy as np

# %%
# Calculate the average distance between each point and its k nearest neighbors
neighbors = NearestNeighbors(n_neighbors=5)  # You can adjust the number of neighbors (k)
neighbors_fit = neighbors.fit(df)
distances, indices = neighbors_fit.kneighbors(df)

# Sort and plot the distances
distances = np.sort(distances, axis=0)
distances = distances[:, 1]  # Get the distances to the kth nearest neighbor
plt.plot(distances)
plt.title('Elbow Method for Determining eps')
plt.xlabel('Data Points (Sorted by Distance)')
plt.ylabel('Distance to kth Nearest Neighbor')
plt.show()

# %%
dbscan = DBSCAN(eps=0.8, min_samples=5) # Replace 0.8 with the optimal eps value from step 2 and experiment with min_samples
dbscan_labels = dbscan.fit_predict(df)

# %%
from sklearn.metrics import silhouette_score
silhouette_score(df, dbscan_labels)
# Out:
# np.float64(-0.023212352954577894)

# %%
# Define linkage criteria to test
linkage_criteria = ['ward', 'complete', 'average', 'single']

# Iterate through linkage criteria and evaluate clustering performance
for linkage in linkage_criteria:
    # Perform hierarchical clustering
    hc = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage=linkage)
    hc_labels = hc.fit_predict(df)

    # Calculate silhouette score
    silhouette = silhouette_score(df, hc_labels)

    # Print results
    print(f"Linkage: {linkage}, Silhouette Score: {silhouette}")

# Choose the linkage criterion with the highest silhouette score
best_linkage = linkage_criteria[np.argmax([silhouette_score(df, AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage=linkage).fit_predict(df)) for linkage in linkage_criteria])]
print(f"\nBest Linkage Criterion: {best_linkage}")
# Out:
# Linkage: ward, Silhouette Score: 0.29665221644571116
# Linkage: complete, Silhouette Score: 0.48534997066391605
# Linkage: average, Silhouette Score: 0.6020945348384437
# Linkage: single, Silhouette Score: 0.575436268987371
#
# Best Linkage Criterion: average

# %%
from sklearn.cluster import KMeans

# Define range of K values to test
k_values = range(1, 11)

# Calculate WCSS for each K value
wcss = []
for k in k_values:
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)

# Plot the Elbow curve
plt.plot(k_values, wcss, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.show()

# Choose the K value at the "elbow" point
# This might be slightly inaccurate, but try the following:
# visually inspect the elbow curve to identify the "elbow" point which corresponds to the optimal K value
# and update the variable 'optimal_k' with the chosen value.
optimal_k = 3

# %%
# Perform K-means clustering with the optimal K value
kmeans = KMeans(n_clusters=optimal_k, init='k-means++', random_state=42)
kmeans_labels = kmeans.fit_predict(df)

# Calculate silhouette score
silhouette = silhouette_score(df, kmeans_labels)

# Print results
print(f"Optimal k: {optimal_k}, Silhouette Score: {silhouette}")
# Out:
# Optimal k: 3, Silhouette Score: 0.37504881877643975

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
import numpy as np

# Define ranges for epsilon and minPts
eps_values = np.arange(0.1, 2.0, 0.1)
min_samples_values = range(2, 10)

# Store results for all combinations
results = []

# Iterate through parameter combinations and evaluate clustering performance
for eps in eps_values:
    for min_samples in min_samples_values:
        # Perform DBSCAN clustering
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        dbscan_labels = dbscan.fit_predict(df)

        # Calculate silhouette score (if there are at least 2 clusters)
        if len(np.unique(dbscan_labels)) > 1:
            silhouette = silhouette_score(df, dbscan_labels)
            results.append((eps, min_samples, silhouette))
            print(f"eps: {eps}, minPts: {min_samples}, Silhouette Score: {silhouette}")

# Find the best parameters
best_eps, best_min_samples, best_silhouette = max(results, key=lambda x: x[2])

# Print the best parameters
print(f"\nBest eps: {best_eps}, Best minPts: {best_min_samples}, Silhouette Score: {best_silhouette}")
# Out:
# eps: 0.1, minPts: 2, Silhouette Score: -0.4444298153579732
# eps: 0.1, minPts: 3, Silhouette Score: -0.2997672253879931
# eps: 0.1, minPts: 4, Silhouette Score: -0.2909422354657219
# eps: 0.1, minPts: 5, Silhouette Score: -0.27246879621615216
# eps: 0.1, minPts: 6, Silhouette Score: -0.24841351746483079
# eps: 0.1, minPts: 7, Silhouette Score: -0.2457567741559135
# eps: 0.1, minPts: 8, Silhouette Score: -0.2439049951336895
# eps: 0.1, minPts: 9, Silhouette Score: -0.2550297189540272
# eps: 0.2, minPts: 2, Silhouette Score: -0.4821855692860137
# eps: 0.2, minPts: 3, Silhouette Score: -0.4493836140236367
# eps: 0.2, minPts: 4, Silhouette Score: -0.26716718658997035
# eps: 0.2, minPts: 5, Silhouette Score: -0.27642044226687695
# eps: 0.2, minPts: 6, Silhouette Score: -0.2788739854227983
# eps: 0.2, minPts: 7, Silhouette Score: -0.2396350296547163
# eps: 0.2, minPts: 8, Silhouette Score: -0.25387415956149495
# eps: 0.2, minPts: 9, Silhouette Score: -0.2533877615989429
# ...

# %%
# Based on the provided code and expected outputs for k=3:
# - Cluster 0: (Potentially) Frequent fliers with high flight miles and transactions but lower balances.
# - Cluster 1: (Potentially) High-value customers with high balances, bonus miles, and bonus transactions but lower flight activity.
# - Cluster 2: (Potentially) Infrequent customers with lower overall engagement across most metrics.

# %%
# Based on the provided code and expected outputs (linkage='ward', n_clusters=3):
# - The clusters generated by Agglomerative Clustering with Ward linkage are likely to be similar to KMeans with k=3.
# - The characteristics of the clusters would align with the insights provided for KMeans above, but potentially with subtle differences.
# - Further analysis would be needed to pinpoint specific differences, focusing on feature means for each cluster.

# %%
# Based on the provided code and expected outputs (eps=0.8, min_samples=5):
# - DBSCAN might identify several core clusters and a significant number of noise points (outliers).
# - The core clusters could represent groups with distinct behavioral patterns, while noise points would be customers with less common characteristics.
# - Interpretation of the core clusters would require examining their feature means and understanding how they differ from each other and from the noise points.

# %%
# Scatter plot using 'Balance' and 'Bonus_miles' features
df['kmeans_cluster'] = kmlabels  # Add the cluster labels to the DataFrame
sns.scatterplot(x='Balance', y='Bonus_miles', hue='kmeans_cluster', data=df, palette='viridis')
plt.title('KMeans Clustering Results')
plt.show()
# Out:
# <ipython-input-54-4f40a45e1033>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['kmeans_cluster'] = kmlabels  # Add the cluster labels to the DataFrame

# %%
# Scatter plot for HC using 'Balance' and 'Bonus_miles' features
df['hc_cluster'] = hclabels  # Add the cluster labels to the DataFrame before plotting
sns.scatterplot(x='Balance', y='Bonus_miles', hue='hc_cluster', data=df, palette='viridis')
plt.title('Hierarchical Clustering Results')
plt.show()

# Scatter plot for DBSCAN using 'Balance' and 'Bonus_miles' features
df['dbscan_cluster'] = dbscan_labels # Add the cluster labels to the DataFrame before plotting
sns.scatterplot(x='Balance', y='Bonus_miles', hue='dbscan_cluster', data=df, palette='viridis')
plt.title('DBSCAN Clustering Results')
plt.show()
# Out:
# <ipython-input-55-e322ccc6fca3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hc_cluster'] = hclabels  # Add the cluster labels to the DataFrame before plotting
# <ipython-input-55-e322ccc6fca3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dbscan_cluster'] = dbscan_labels # Add the cluster labels to the DataFrame before plotting

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Balance'], df['Bonus_miles'], df['Flight_miles_12mo'], c=df['kmeans_cluster'], cmap='viridis')
ax.set_xlabel('Balance')
ax.set_ylabel('Bonus_miles')
ax.set_zlabel('Flight_miles_12mo')
plt.title('KMeans Clustering Results (3D)')
plt.show()

# %%
# Scatter plot for HC using 'Balance' and 'Bonus_miles' features
sns.scatterplot(x='Balance', y='Bonus_miles', hue='hc_cluster', data=df, palette='viridis')
plt.title('Hierarchical Clustering Results')
plt.show()

# Scatter plot for DBSCAN using 'Balance' and 'Bonus_miles' features
sns.scatterplot(x='Balance', y='Bonus_miles', hue='dbscan_cluster', data=df, palette='viridis')
plt.title('DBSCAN Clustering Results')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# 3D scatter plot for HC
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Balance'], df['Bonus_miles'], df['Flight_miles_12mo'], c=df['hc_cluster'], cmap='viridis')
ax.set_xlabel('Balance')
ax.set_ylabel('Bonus_miles')
ax.set_zlabel('Flight_miles_12mo')
plt.title('Hierarchical Clustering Results (3D)')
plt.show()

# 3D scatter plot for DBSCAN
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['Balance'], df['Bonus_miles'], df['Flight_miles_12mo'], c=df['dbscan_cluster'], cmap='viridis')
ax.set_xlabel('Balance')
ax.set_ylabel('Bonus_miles')
ax.set_zlabel('Flight_miles_12mo')
plt.title('DBSCAN Clustering Results (3D)')
plt.show()

# %%
kmeans_silhouette = silhouette_score(df, kmeans_labels)
print(f"Silhouette Score for K-Means: {kmeans_silhouette}")
# Out:
# Silhouette Score for K-Means: 0.3978585985498006

# %%
# Silhouette score is not defined for clusters with only one data point, so filter those out:
# Get indices of data points assigned to clusters (excluding noise points labeled as -1)
clustered_indices = dbscan_labels != -1

# Calculate silhouette score only for clustered data points
if len(set(dbscan_labels)) > 1: # Ensure at least 2 clusters for Silhouette Score calculation
    dbscan_silhouette = silhouette_score(df[clustered_indices], dbscan_labels[clustered_indices])
    print(f"Silhouette Score for DBSCAN: {dbscan_silhouette}")
else:
    print("Silhouette Score for DBSCAN cannot be calculated as there is only one cluster (including noise).")
# Out:
# Silhouette Score for DBSCAN: 0.29736007047899454

# %%
hc_silhouette = silhouette_score(df, hc_labels)
print(f"Silhouette Score for Hierarchical Clustering: {hc_silhouette}")
# Out:
# Silhouette Score for Hierarchical Clustering: 0.5694392897300363
