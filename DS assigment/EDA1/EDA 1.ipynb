# %% [markdown]
# ## Exploratory Data Analysis on a Dataset

# %% [markdown]
# ###Objective:
#
# The main goal of this assignment is to conduct a thorough exploratory analysis of the "cardiographic.csv" dataset to uncover insights, identify patterns, and understand the dataset's underlying structure. You will use statistical summaries, visualizations, and data manipulation techniques to explore the dataset comprehensively.

# %% [markdown]
# ___

# %% [markdown]
# ###1. Data Cleaning and Preparation:
# * Load the dataset into a DataFrame or equivalent data structure.
# * Handle missing values appropriately (e.g., imputation, deletion).
# * Identify and correct any inconsistencies in data types (e.g., numerical values stored as strings).
# * Detect and treat outliers if necessary.

# %%
import pandas as pd
df=pd.read_csv("/content/Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.shape
# Out:
# (2126, 14)

# %%
df.columns
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df_new = df.fillna(df.median())

# %%
df_new.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df_new.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.340204     0.003204     0.009894     0.004391     0.001895
# std      11.214379     0.004373     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000002     0.000173    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
df_new.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
for i in df_new.columns:
  df_new[i] = pd.to_numeric(df_new[i], errors='coerce')

# %%
df_new.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
import numpy as np
from scipy.stats import skew, kurtosis

# %%
for i in df_new.columns:
  print(f"{i}")
  print(f"Mean of {i}: {np.mean(df_new[i])}")
  print(f"Median of {i}: {np.median(df_new[i])}")
  print(f"Standard Deviation of {i}: {np.std(df_new[i])}")
  print(f"Skewness of {i}: {(df_new[i].skew())}")
  print(f"Kurtosis of {i}: {df_new[i].kurtosis()}\n")
# Out:
# LB
# Mean of LB: 133.34020439197982
# Median of LB: 133.0
# Standard Deviation of LB: 11.211741731813301
# Skewness of LB: 0.32324480250458326
# Kurtosis of LB: 11.357729118709976
#
# AC
# Mean of AC: 0.0032040677335103004
# Median of AC: 0.001633991
# Standard Deviation of AC: 0.004371711563273403
# Skewness of AC: 2.0323962750022546
# Kurtosis of AC: 12.65551778302331
#
# FM
# Mean of FM: 0.009894484174097834
# Median of FM: 0.0
# Standard Deviation of FM: 0.06752379360748116
# Skewness of FM: 6.75306980198638
# Kurtosis of FM: 94.47225711217186
#
# UC
# Mean of UC: 0.004390615424744109
# Median of UC: 0.004484305
# Standard Deviation of UC: 0.0033396765171735355
# Skewness of UC: 0.9742394510625922
# Kurtosis of UC: 10.127511712089646
#
# DL
# Mean of DL: 0.0018953447635069313
# Median of DL: 0.0
# Standard Deviation of DL: 0.0033418960481360277
# Skewness of DL: 2.0103895349327043
# Kurtosis of DL: 12.85792594177082
#
# DS
# Mean of DS: 2.484200507770529e-06
# Median of DS: 0.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for i in df_new.columns:
    plt.figure(figsize=(6, 3))
    sns.histplot(df_new[i], bins=30, kde=True)
    plt.title(f"Distribution of {i}")
    plt.show()

# %%
# Compute Q1, Q3, and IQR for each column
Q1 = df_new.quantile(0.25)
Q3 = df_new.quantile(0.75)
IQR = Q3 - Q1

# Define outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Count outliers in each column
outliers = ((df_new < lower_bound) | (df_new > upper_bound)).sum()
print("Number of outliers per column:\n", outliers)
# Out:
# Number of outliers per column:
#  LB           10
# AC           43
# FM          347
# UC           13
# DL          125
# DS          120
# DP          284
# ASTV         10
# MSTV         80
# ALTV        318
# MLTV         81
# Width        10
# Tendency     10
# NSP         559
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 10))

# Before treatment
plt.subplot(1, 2, 1)
sns.boxplot(data=df_new)
plt.xticks(rotation=90)
plt.title("Before Outlier Treatment")
# Out:
# Text(0.5, 1.0, 'Before Outlier Treatment')

# %%
# Create a copy to avoid modifying the original data
df2 = df_new.copy()

# Replace outliers with median
for col in df_new.columns:
    median_value = df_new[col].median()
    df2[col] = np.where(
        (df_new[col] < lower_bound[col]) | (df_new[col] > upper_bound[col]),
        median_value,  # Replace outliers with median
        df_new[col]    # Keep original value if not an outlier
    )

# %%
# Check if outliers remain
outliers_after = ((df2 < lower_bound) | (df2 > upper_bound)).sum()
print("Number of outliers per column after replacement:\n", outliers_after)
# Out:
# Number of outliers per column after replacement:
#  LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# _____

# %% [markdown]
# ###2. Statistical Summary:
# * Provide a statistical summary for each variable in the dataset, including measures of central tendency (mean, median) and dispersion (standard deviation, interquartile range).
# * Highlight any interesting findings from this summary.

# %%
import numpy as np

# Compute summary statistics
summary_stats = pd.DataFrame({
    "Mean": df2.mean(),
    "Median": df2.median(),
    "Standard Deviation": df2.std(),
    "Q1 (25th percentile)": df2.quantile(0.25),
    "Q3 (75th percentile)": df2.quantile(0.75),
    "IQR (Q3 - Q1)": df2.quantile(0.75) - df2.quantile(0.25)
})

# Display the statistical summary
print("\nStatistical Summary of Dataset:\n")
print(summary_stats)
# Out:
# Statistical Summary of Dataset:
#
#                 Mean      Median  Standard Deviation  Q1 (25th percentile)  \
# LB        133.263990  133.000000            9.743481            126.000000
# AC          0.002924    0.001634            0.003498              0.000000
# FM          0.000554    0.000000            0.001300              0.000000
# UC          0.004341    0.004484            0.002911              0.001880
# DL          0.001324    0.000000            0.002156              0.000000
# DS          0.000000    0.000000            0.000000              0.000000
# DP          0.000000    0.000000            0.000000              0.000000
# ASTV       46.993632   49.000000           17.157976             32.000000
# MSTV        1.235030    1.200000            0.685014              0.700000
# ALTV        2.640408    0.000000            5.748781              0.000000
# MLTV        7.581930    7.400000            4.438028              4.696705
# ...

# %% [markdown]
#  Observations & Insights
# Baseline Fetal Heart Rate (LB)
#
# Mean: 133.26 bpm
# Median: 133 bpm
# IQR: 14 bpm
# Insight: The distribution seems symmetric since the mean and median are very close.
# Accelerations (AC) & Fetal Movements (FM)
#
# Mean AC: 0.0029, Mean FM: 0.00055
# Median AC: 0.0016, Median FM: 0.0000
# Insight: The median being 0 suggests that many observations have no accelerations or fetal movements.
# Decelerations (DL, DS, DP)
#
# All median values are 0, indicating that prolonged and short decelerations rarely occur.
# Insight: Most fetal heart rate patterns might not show concerning decelerations.
# Short-Term (ASTV, MSTV) & Long-Term Variability (ALTV, MLTV)
#
# ASTV Mean: 46.99%, Median: 49%
# IQR for ASTV: 29% → Shows a wide variability.
# Insight: The high variability in ASTV suggests differences in fetal health status among cases.
# Width & Tendency
#
# Width Mean: 70.28, Median: 67
# Tendency Median: 0 (suggests most cases have no significant trend).
# NSP (Fetal Health Classification)
#
# Mean & Median: 1.0, IQR: 0
# Insight: This indicates that most cases belong to the first category (possibly normal fetal state).

# %% [markdown]
# ###3. Data Visualization:
# * Create histograms or boxplots to visualize the distributions of various numerical variables.
# * Use bar charts or pie charts to display the frequency of categories for categorical variables.
# * Generate scatter plots or correlation heatmaps to explore relationships between pairs of variables.
# * Employ advanced visualization techniques like pair plots, or violin plots for deeper insights.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for plots
sns.set(style="whitegrid")

# Create histograms for all numerical columns
for col in df.columns:
    plt.figure(figsize=(6, 3))
    sns.histplot(df[col], bins=30)
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
# Bar charts (by binning numerical values)
for col in df_new.columns:
    plt.figure(figsize=(6, 4))
    df_new[col].plot(kind='hist', bins=10, color="goldenrod", alpha=0.7, edgecolor="black")
    plt.title(f"Bar Chart of {col} (Binned)")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter Plots: Pairwise relationships
for col1 in df_new.columns:
    for col2 in df_new.columns:
        if col1 != col2:  # Avoid self-correlation plots
            plt.figure(figsize=(6, 4))
            sns.scatterplot(x=df_new[col1], y=df_new[col2], alpha=0.5, color="royalblue")
            plt.title(f"Scatter Plot: {col1} vs {col2}")
            plt.xlabel(col1)
            plt.ylabel(col2)
            plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Correlation Heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df_new.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Pair Plot - Visualizing relationships between all numerical variables
sns.pairplot(df_new, diag_kind="kde")
plt.show()

# %%
# Violin Plots - Distribution of each numerical variable
plt.figure(figsize=(15, 8))
for i, col in enumerate(df_new.columns, 1):
    plt.subplot(3, 5, i)  # Adjust layout for better display
    sns.violinplot(y=df_new[col], color="skyblue")
    plt.title(f"Violin Plot of {col}")
    plt.xlabel("")
plt.tight_layout()
plt.show()

# %% [markdown]
# ###4. Pattern Recognition and Insights:
# * Identify any correlations between variables and discuss their potential implications.
# * Look for trends or patterns over time if temporal data is available.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation matrix
corr_matrix = df_new.corr()

# Heatmap for Correlation Analysis
plt.figure(figsize=(12, 6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# Scatter Plots for Strongly Correlated Pairs (Threshold: |correlation| > 0.7)
strong_corr = corr_matrix.abs().unstack().sort_values(ascending=False)
strong_corr = strong_corr[strong_corr.between(0.7, 1) & (strong_corr < 1)]

if not strong_corr.empty:
    for (col1, col2), value in strong_corr.items():
        plt.figure(figsize=(6, 4))
        sns.scatterplot(x=df_new[col1], y=df_new[col2], alpha=0.6)
        plt.title(f"Scatter Plot: {col1} vs {col2} (Corr: {value:.2f})")
        plt.xlabel(col1)
        plt.ylabel(col2)
        plt.show()
else:
    print("No strongly correlated variable pairs found.")

# Check Trends Over Time if Temporal Data Exists
if "Time" in df_new.columns:  # Replace 'Time' with the actual time column if available
    plt.figure(figsize=(12, 5))
    sns.lineplot(x=df_new["Time"], y=df_new["LB"])  # Example using "LB"
    plt.title("Trend of LB Over Time")
    plt.xlabel("Time")
    plt.ylabel("LB")
    plt.show()
else:
    print("No temporal data found to analyze trends.")
# Out:
# No strongly correlated variable pairs found.
# No temporal data found to analyze trends.

# %% [markdown]
# ###5. Conclusion:
# * Summarize the key insights and patterns discovered through your exploratory analysis.
# * Discuss how these findings could impact decision-making or further analyses.

# %% [markdown]
# ###Deliverables:
#
# A brief report summarizing your findings, insights, and any recommendations for further analysis or actions based on the data.
