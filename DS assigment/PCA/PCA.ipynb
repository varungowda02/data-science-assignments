# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/DS assigment/PCA/wine.csv")
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.columns
# Out:
# Index(['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
#        'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
#        'Dilution', 'Proline'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Type                 int64
# Alcohol            float64
# Malic              float64
# Ash                float64
# Alcalinity         float64
# Magnesium            int64
# Phenols            float64
# Flavanoids         float64
# Nonflavanoids      float64
# Proanthocyanins    float64
# Color              float64
# Hue                float64
# Dilution           float64
# Proline              int64
# dtype: object

# %%
df.nunique()
# Out:
# Type                 3
# Alcohol            126
# Malic              133
# Ash                 79
# Alcalinity          63
# Magnesium           53
# Phenols             97
# Flavanoids         132
# Nonflavanoids       39
# Proanthocyanins    101
# Color              132
# Hue                 78
# Dilution           122
# Proline            121
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
z_score=(df-df.mean())/df.std()
z_score
# Out:
#          Type   Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0   -1.210529  1.514341 -0.560668  0.231400   -1.166303   1.908522  0.806722
# 1   -1.210529  0.245597 -0.498009 -0.825667   -2.483841   0.018094  0.567048
# 2   -1.210529  0.196325  0.021172  1.106214   -0.267982   0.088110  0.806722
# 3   -1.210529  1.686791 -0.345835  0.486554   -0.806975   0.928300  2.484437
# 4   -1.210529  0.294868  0.227053  1.835226    0.450674   1.278379  0.806722
# ..        ...       ...       ...       ...         ...        ...       ...
# 173  1.370000  0.873810  2.966176  0.304301    0.300954  -0.331985 -0.982841
# 174  1.370000  0.491955  1.408636  0.413653    1.049555   0.158126 -0.791103
# 175  1.370000  0.331822  1.739837 -0.388260    0.151234   1.418411 -1.126646
# 176  1.370000  0.208643  0.227053  0.012696    0.151234   1.418411 -1.030776
# 177  1.370000  1.391162  1.578712  1.361368    1.498716  -0.261969 -0.391646
#
# ...

# %%
c=df.cov()
c
# Out:
#                        Type     Alcohol      Malic        Ash  Alcalinity  \
# Type               0.600679   -0.206515   0.379039  -0.010555    1.340364
# Alcohol           -0.206515    0.659062   0.085611   0.047115   -0.841093
# Malic              0.379039    0.085611   1.248015   0.050277    1.076332
# Ash               -0.010555    0.047115   0.050277   0.075265    0.406208
# Alcalinity         1.340364   -0.841093   1.076332   0.406208   11.152686
# Magnesium         -2.315495    3.139878  -0.870780   1.122937   -3.974760
# Phenols           -0.348835    0.146887  -0.234338   0.022146   -0.671149
# Flavanoids        -0.656091    0.192033  -0.458630   0.031535   -1.172083
# Nonflavanoids      0.047177   -0.015754   0.040733   0.006358    0.150422
# Proanthocyanins   -0.221413    0.063518  -0.141147   0.001516   -0.377176
# Color              0.477339    1.028283   0.644838   0.164654    0.145024
# Hue               -0.109368   -0.013313  -0.143326  -0.004682   -0.209118
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df.hist(figsize=(10,9), bins=30)
plt.suptitle("Histogram")
plt.show()

# %%
for i in df.columns:
  plt.figure(figsize=(15,4))
  sns.boxplot(df[i], orient='h')
  plt.title("Boxplot")
  plt.show()

# %%
import scipy.stats as stats
threshold=3
z=np.abs(stats.zscore(df))
df=df[(z<threshold).all(axis=1)]

# %%
from scipy.stats import skew, kurtosis

# %%
for i in df.columns:
  print(f'Skewness of {i}: {df[i].skew()}')
  print(f'Kurtosis of {i}: {df[i].kurtosis()}\n')
# Out:
# Skewness of Type: 0.11705323276050587
# Kurtosis of Type: -1.386156214785573
#
# Skewness of Alcohol: -0.028037678403123174
# Kurtosis of Alcohol: -0.9492013970437387
#
# Skewness of Malic: 0.9662530181320802
# Kurtosis of Malic: 0.07403623864726327
#
# Skewness of Ash: -0.25043768391593274
# Kurtosis of Ash: -0.027903637726634845
#
# Skewness of Alcalinity: 0.10477418655816431
# Kurtosis of Alcalinity: 0.12733883713813077
#
# Skewness of Magnesium: 0.5665215651666302
# Kurtosis of Magnesium: 0.03467525364413282
#
# Skewness of Phenols: 0.1321082282733158
# Kurtosis of Phenols: -0.8158394191192229
#
# Skewness of Flavanoids: -0.07720509103684343
# Kurtosis of Flavanoids: -1.237409747152002
#
# Skewness of Nonflavanoids: 0.48180972340790235
# Kurtosis of Nonflavanoids: -0.5910250750363835
#
# Skewness of Proanthocyanins: 0.3602170711347917
# Kurtosis of Proanthocyanins: 0.03761689763146814
#
# Skewness of Color: 0.7325796658160038
# Kurtosis of Color: -0.03348847516246867
#
# ...

# %%
for i in df.columns:
  plt.figure(figsize=(10,8))
  sns.histplot(df[i], kde=True)
  plt.title(f'Distribution of {i}')
  plt.show()

# %%
corr=df.corr()
corr
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.358159  0.466193 -0.041083    0.572880
# Alcohol         -0.358159  1.000000  0.094430  0.208414   -0.355508
# Malic            0.466193  0.094430  1.000000  0.201007    0.322212
# Ash             -0.041083  0.208414  0.201007  1.000000    0.357721
# Alcalinity       0.572880 -0.355508  0.322212  0.357721    1.000000
# Magnesium       -0.237956  0.384287  0.001273  0.356159   -0.200760
# Phenols         -0.750019  0.335947 -0.374547  0.098304   -0.450440
# Flavanoids      -0.884289  0.299956 -0.473367  0.025495   -0.507554
# Nonflavanoids    0.507436 -0.182249  0.325362  0.126694    0.374967
# Proanthocyanins -0.577886  0.215285 -0.277069  0.010541   -0.328975
# Color            0.255763  0.531866  0.287016  0.220942   -0.019411
# Hue             -0.648309 -0.008638 -0.568239 -0.069079   -0.336831
# Dilution        -0.802703  0.111289 -0.407781 -0.052576   -0.382824
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df_scaled=scaler.fit_transform(df)

# %%
df=pd.DataFrame(df_scaled, columns=df.columns)
df
# Out:
#          Type   Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0   -1.186165  1.513539 -0.578842  0.250637   -1.209653   2.253466  0.840250
# 1   -1.186165  0.210929 -0.514888 -0.945351   -2.624711   0.097439  0.600640
# 2   -1.186165  0.160342  0.015009  1.240421   -0.244840   0.177292  0.840250
# 3   -1.186165  1.690593 -0.359574  0.539324   -0.823728   1.135526  2.517517
# 4   -1.186165  0.261516  0.225141  2.065240    0.527010   1.534790  0.840250
# ..        ...       ...       ...       ...         ...        ...       ...
# 163  1.352379  0.855910  3.020809  0.333119    0.366208  -0.301825 -0.948835
# 164  1.352379  0.463863  1.431116  0.456842    1.170218   0.257145 -0.757147
# 165  1.352379  0.299456  1.769154 -0.450459    0.205406   1.694496 -1.092601
# 166  1.352379  0.172989  0.225141  0.003191    0.205406   1.694496 -0.996757
# 167  1.352379  1.387072  1.604703  1.529107    1.652624  -0.221972 -0.357798
#
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA()
df_pca=pca.fit_transform(df)

# %%
explained_variance=pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.42138058, 0.18685543, 0.0892958 , 0.06171747, 0.05607154,
#        0.04503336, 0.03526237, 0.02436699, 0.02162974, 0.01918179,
#        0.01600856, 0.01176377, 0.00836792, 0.00306467])

# %%
plt.figure(figsize=(10,5))
plt.plot(range(1, len(explained_variance)+1), explained_variance, marker="o")
plt.title("Explained Variance Ratio")
plt.xlabel("Number of Components")
plt.ylabel("Explained Variance Ratio")
plt.show()

# %%
cummulative_variance=explained_variance.cumsum()
cummulative_variance
# Out:
# array([0.42138058, 0.60823601, 0.69753181, 0.75924929, 0.81532083,
#        0.86035418, 0.89561655, 0.91998355, 0.94161329, 0.96079508,
#        0.97680364, 0.9885674 , 0.99693533, 1.        ])

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1, len(cummulative_variance)+1), cummulative_variance, marker="o")
plt.title("Cummulative Explained Variance")
plt.xlabel("Number of Components")
plt.ylabel("Cummulative Variance")
plt.axhline(y=0.95, color='red', linestyle="--")
plt.show()

# %%
n_components=2
pca=PCA(n_components=n_components)
df_pca_trans=pca.fit_transform(df)

# %%
df_pca=pd.DataFrame(df_pca_trans, columns=[f"PC{i+1}" for i in range(n_components)])

# %%
df_pca
# Out:
#           PC1       PC2
# 0    3.665097  1.586766
# 1    2.663560 -0.328564
# 2    2.876577  0.940561
# 3    4.035396  2.717890
# 4    1.405724  0.980778
# ..        ...       ...
# 163 -3.582182  2.263374
# 164 -2.917887  1.807345
# 165 -2.941601  3.004387
# 166 -2.665658  2.501472
# 167 -3.477963  2.748312
#
# [168 rows x 2 columns]

# %%
df
# Out:
#          Type   Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0   -1.186165  1.513539 -0.578842  0.250637   -1.209653   2.253466  0.840250
# 1   -1.186165  0.210929 -0.514888 -0.945351   -2.624711   0.097439  0.600640
# 2   -1.186165  0.160342  0.015009  1.240421   -0.244840   0.177292  0.840250
# 3   -1.186165  1.690593 -0.359574  0.539324   -0.823728   1.135526  2.517517
# 4   -1.186165  0.261516  0.225141  2.065240    0.527010   1.534790  0.840250
# ..        ...       ...       ...       ...         ...        ...       ...
# 163  1.352379  0.855910  3.020809  0.333119    0.366208  -0.301825 -0.948835
# 164  1.352379  0.463863  1.431116  0.456842    1.170218   0.257145 -0.757147
# 165  1.352379  0.299456  1.769154 -0.450459    0.205406   1.694496 -1.092601
# 166  1.352379  0.172989  0.225141  0.003191    0.205406   1.694496 -0.996757
# 167  1.352379  1.387072  1.604703  1.529107    1.652624  -0.221972 -0.357798
#
# ...

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=3, random_state=42)
original_cl=kmeans.fit_predict(df)

# %%
df['Cluster']=original_cl
df
# Out:
#          Type   Alcohol     Malic       Ash  Alcalinity  Magnesium   Phenols  \
# 0   -1.186165  1.513539 -0.578842  0.250637   -1.209653   2.253466  0.840250
# 1   -1.186165  0.210929 -0.514888 -0.945351   -2.624711   0.097439  0.600640
# 2   -1.186165  0.160342  0.015009  1.240421   -0.244840   0.177292  0.840250
# 3   -1.186165  1.690593 -0.359574  0.539324   -0.823728   1.135526  2.517517
# 4   -1.186165  0.261516  0.225141  2.065240    0.527010   1.534790  0.840250
# ..        ...       ...       ...       ...         ...        ...       ...
# 163  1.352379  0.855910  3.020809  0.333119    0.366208  -0.301825 -0.948835
# 164  1.352379  0.463863  1.431116  0.456842    1.170218   0.257145 -0.757147
# 165  1.352379  0.299456  1.769154 -0.450459    0.205406   1.694496 -1.092601
# 166  1.352379  0.172989  0.225141  0.003191    0.205406   1.694496 -0.996757
# 167  1.352379  1.387072  1.604703  1.529107    1.652624  -0.221972 -0.357798
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=df.Alcohol, y=df.Flavanoids, hue=original_cl, palette='viridis')
plt.title("Original Clusters")
plt.xlabel("Alcohol")
plt.ylabel("Flavanoids")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.pairplot(df, hue='Cluster')
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score
print("Silhouette Score: ", silhouette_score(df, original_cl))
print("Davies Bouldin Score: ", davies_bouldin_score(df, original_cl))
# Out:
# Silhouette Score:  0.35208842148234465
# Davies Bouldin Score:  1.1792312911787917

# %%
kmeans_pca=KMeans(n_clusters=3, random_state=42)
pca_cl=kmeans_pca.fit_predict(df_pca)

# %%
df_pca['Cluster']=pca_cl
df_pca
# Out:
#           PC1       PC2  Cluster
# 0    3.665097  1.586766        2
# 1    2.663560 -0.328564        2
# 2    2.876577  0.940561        2
# 3    4.035396  2.717890        2
# 4    1.405724  0.980778        2
# ..        ...       ...      ...
# 163 -3.582182  2.263374        1
# 164 -2.917887  1.807345        1
# 165 -2.941601  3.004387        1
# 166 -2.665658  2.501472        1
# 167 -3.477963  2.748312        1
#
# [168 rows x 3 columns]

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=df_pca['PC1'], y=df_pca['PC2'], hue=pca_cl, palette='viridis')
plt.title('PCA Clusters')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.pairplot(df_pca, hue='Cluster')
plt.show()

# %%
print("Silhouette Score: ", silhouette_score(df, pca_cl))
print("Davies Bouldin Score: ", davies_bouldin_score(df, pca_cl))
# Out:
# Silhouette Score:  0.3499366629176317
# Davies Bouldin Score:  1.1767385841422175

# %% [markdown]
# ### **Comparison of Clustering Results: Original vs PCA-Transformed Data**
#
# #### **1. Silhouette Score**
# - Measures how well clusters are separated (range: -1 to 1, higher is better).
# - **Original Data**: **0.3521**
# - **PCA-Transformed Data**: **0.3499**
# - The scores are very close, indicating that PCA does not significantly improve or degrade the clustering quality.
#
# #### **2. Davies-Bouldin Score**
# - Measures the compactness and separation of clusters (lower is better).
# - **Original Data**: **1.1792**
# - **PCA-Transformed Data**: **1.1767**
# - A slight decrease in DB score after PCA suggests that PCA might have improved cluster separation slightly.
#
# ### **Interpretation**
# - **PCA slightly reduces the Davies-Bouldin score**, meaning clusters might be more compact and better separated.
# - **Silhouette scores remain almost unchanged**, indicating that the clustering structure is similar before and after PCA.
# - **PCA does not significantly enhance clustering performance** in this case, but it could still be useful for dimensionality reduction and visualization.

# %% [markdown]
# ---
#
# ### Task 5: Comparison and Analysis
#
# #### Compare the Clustering Results Obtained from the Original Dataset and PCA-Transformed Data
# - **Metrics**:
#   - **Original Data**:
#     - Silhouette Score: 0.3521
#     - Davies-Bouldin Score: 1.1792
#   - **PCA-Transformed Data**:
#     - Silhouette Score: 0.3499
#     - Davies-Bouldin Score: 1.1767
# - **Quantitative Comparison**:
#   - **Silhouette Score**: The original data scores slightly higher (0.3521 vs. 0.3499), a difference of -0.0022 (~0.6% decrease). This score measures how well-separated and cohesive clusters are (higher = better).
#   - **Davies-Bouldin Score**: The PCA-transformed data scores slightly lower (1.1767 vs. 1.1792), a difference of -0.0025 (~0.2% decrease). This score assesses cluster compactness and separation (lower = better).
#
# #### Discuss Any Similarities or Differences Observed in the Clustering Results
# - **Similarities**:
#   - **Clustering Quality**: Both Silhouette Scores (~0.35) are moderate, suggesting decent but not exceptional cluster separation and cohesion in both datasets. This indicates that the core clustering structure—likely reflecting the 3 wine types—is preserved across both approaches.
#   - **Stability**: The tiny differences in metrics (Silhouette: -0.0022, Davies-Bouldin: -0.0025) imply that PCA does not drastically alter the clustering outcome. The same general patterns are captured, with clusters remaining consistent in their overall arrangement.
# - **Differences**:
#   - **Silhouette Score**: The slight drop after PCA (0.3521 to 0.3499) suggests a minor reduction in how well points fit their clusters relative to others. This could mean PCA discards some subtle variance that aids separation.
#   - **Davies-Bouldin Score**: The small improvement after PCA (1.1792 to 1.1767) indicates slightly tighter or better-separated clusters. PCA might reduce noise or redundant features (e.g., correlated variables like Phenols and Flavanoids), enhancing cluster definition.
#
# #### Reflect on the Impact of Dimensionality Reduction on Clustering Performance
# - **What PCA Does**: PCA reduces the 13 original features to fewer principal components (e.g., 2 or 3, though not specified), retaining most variance while eliminating less significant dimensions.
# - **Performance Impact**:
#   - **Minimal Change**: The near-identical Silhouette Scores show that PCA preserves the key clustering structure, with only a slight loss in cohesion/separation. The Davies-Bouldin improvement suggests PCA may filter noise, making clusters marginally more compact or distinct.
#   - **Variance Trade-off**: The small metric shifts imply that the discarded dimensions (e.g., beyond 95% cumulative variance) contain little clustering-relevant information. However, the slight Silhouette drop hints at a minor loss of fine-grained detail.
# - **Overall Effect**: Dimensionality reduction has a negligible impact on clustering quality for this dataset. It maintains performance while simplifying the data, which is valuable for computational efficiency and visualization.
#
# #### Analyze the Trade-offs Between Using PCA and Clustering Directly on the Original Dataset
# - **Using PCA**:
#   - **Advantages**:
#     - **Efficiency**: Fewer dimensions (e.g., 2-3 vs. 13) reduce computation time and memory use, especially beneficial for larger datasets.
#     - **Noise Reduction**: The Davies-Bouldin improvement suggests PCA may remove noise or redundancy, slightly enhancing cluster quality.
#     - **Visualization**: PCA enables 2D/3D scatter plots, making it easier to interpret clustering results visually.
#   - **Disadvantages**:
#     - **Information Loss**: The slight Silhouette drop indicates some loss of variance, potentially missing subtle patterns in the data.
#     - **Complexity**: Requires additional steps (standardization, PCA fitting), adding preprocessing overhead.
# - **Using Original Data**:
#   - **Advantages**:
#     - **Full Information**: Retains all 13 features, capturing every detail (reflected in the slightly higher Silhouette Score).
#     - **Simplicity**: Direct clustering skips PCA, reducing preprocessing steps.
#   - **Disadvantages**:
#     - **Redundancy/Noise**: Correlated features (e.g., Phenols and Flavanoids) or noise might dilute cluster quality, as hinted by the higher Davies-Bouldin Score.
#     - **Scalability**: More features increase computational cost, less practical for high-dimensional data.
# - **Trade-off Summary**: PCA offers efficiency and slight quality tweaks (better Davies-Bouldin) at the cost of minor detail loss (worse Silhouette). Original data preserves all information but may include unnecessary complexity.
#
# ---
#
# ### Task 6: Conclusion and Insights
#
# #### Summarize the Key Findings and Insights from the Assignment
# - **Clustering Performance**: Clustering on the original Wine dataset (Silhouette: 0.3521, Davies-Bouldin: 1.1792) and PCA-transformed data (Silhouette: 0.3499, Davies-Bouldin: 1.1767) yields nearly identical results. PCA slightly improves cluster compactness/separation (Davies-Bouldin) but slightly reduces cohesion/separation (Silhouette).
# - **PCA Impact**: Dimensionality reduction retains the core clustering structure, with minimal quality trade-offs. The 13 features are likely reduced to 2-3 components capturing most variance, losing little discriminatory power.
# - **Key Insight**: For this dataset, PCA’s benefits (efficiency, noise reduction) outweigh its minor drawbacks (slight information loss), making it a viable preprocessing step without sacrificing much clustering accuracy.
#
# #### Discuss the Practical Implications of Using PCA and Clustering in Data Analysis
# - **PCA**:
#   - **Scalability**: Reduces computational load, critical for large, high-dimensional datasets (e.g., genomics, image data).
#   - **Visualization**: Simplifies exploration (e.g., 2D plots of wine clusters), aiding interpretation in real-world applications like quality control or customer segmentation.
#   - **Preprocessing**: Removes noise/redundancy, potentially improving downstream tasks like classification or clustering when features are correlated.
# - **Clustering**:
#   - **Pattern Discovery**: Identifies natural groupings (e.g., wine types), useful in market analysis, biology, or anomaly detection.
#   - **Evaluation**: Metrics like Silhouette and Davies-Bouldin quantify cluster quality, guiding model selection in practical settings.
# - **Combined Use**: PCA followed by clustering streamlines analysis, balancing efficiency and insight. Here, it maintains quality while simplifying the 13-feature Wine dataset, suggesting it’s practical for similar moderate-sized, correlated datasets.
#
# #### Provide Recommendations for When to Use Each Technique Based on the Analysis Conducted
# - **Use PCA Before Clustering**:
#   - **When**: Features are numerous (e.g., >10) or highly correlated (e.g., Phenols and Flavanoids), computational resources are limited, or visualization is needed.
#   - **Why**: PCA reduces complexity with minimal quality loss (as seen here), making it ideal for large datasets or when interpretability matters.
#   - **Example**: Analyzing customer data with many redundant metrics (e.g., purchase frequency, total spend).
# - **Cluster Directly on Original Data**:
#   - **When**: Dataset is small-to-medium (e.g., 178 samples, 13 features), features are diverse and uncorrelated, or every detail is critical (e.g., scientific research).
#   - **Why**: Retains all information (slight Silhouette edge), avoiding potential loss of subtle patterns PCA might discard.
#   - **Example**: Small-scale chemical analysis where all wine properties are uniquely informative.
# - **Hybrid Approach**: For datasets like Wine, where differences are minor, use PCA for initial exploration (e.g., visualization) and validate with original data if precision is paramount.
#
# ---
#
# ### Final Takeaway
# The Wine dataset analysis shows PCA and direct clustering perform similarly, with PCA offering practical benefits (efficiency, visualization) for a small quality trade-off. Choose PCA for scalability and simplicity, and original data for maximum fidelity, depending on your analysis goals.
